# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns

# %% [markdown]
# ## Read Benchmark data

# %%
path = r'C:\Users\127ri\Desktop\MSBA\Apps\Coding\UJAFEDNY\Data\Case Study for Internship 2023 03 - Copy.xlsx'

# %%
bm_df = pd.read_excel(path, sheet_name='Benchmark')

# %%
bm_df.head(20)
# Out:
#              Unnamed: 0  \
# 0             Shortname
# 1              Longname
# 2                  Code
# 3                  Type
# 4                   CCY
# 5                 blank
# 6                 blank
# 7                 blank
# 8                 blank
# 9   1988-01-31 00:00:00
# 10  1988-02-29 00:00:00
# 11  1988-03-31 00:00:00
# 12  1988-04-30 00:00:00
# 13  1988-05-31 00:00:00
# 14  1988-06-30 00:00:00
# 15  1988-07-31 00:00:00
# 16  1988-08-31 00:00:00
# 17  1988-09-30 00:00:00
# 18  1988-10-31 00:00:00
# 19  1988-11-30 00:00:00
#
#    Bloomberg BENCHMARKS (Make sure funds are listed in the same order as on BB tab)  \
# 0                                           MSCI ACWI
# 1                                           MSCI ACWI
# 2                                                 NaN
# 3                                                  BM
# 4                                                 USD
# 5                                                 NaN
# ...

# %% [markdown]
# ### Set shortname as benchmark names

# %%
bm_df.columns = bm_df.iloc[0]
bm_df.head()
# Out:
# 0  Shortname  MSCI ACWI  S&P 500    BarCap US Agg  BarCap High Yield  \
# 0  Shortname  MSCI ACWI  S&P 500    BarCap US Agg  BarCap High Yield
# 1   Longname  MSCI ACWI  S&P 500  Barclays US Agg  BarCap High Yield
# 2       Code        NaN      NaN              NaN                NaN
# 3       Type         BM       BM               BM                 BM
# 4        CCY        USD      USD              USD                USD
#
# 0  BarCap Global Agg  MSCI Emerging Markets  Russell 2500 Index  \
# 0  BarCap Global Agg  MSCI Emerging Markets  Russell 2500 Index
# 1  BarCap Global Agg             MSCI EM TR  Russell 2500 Index
# 2                NaN                    NaN                 NaN
# 3                 BM                     BM                  BM
# 4                USD                    USD                 USD
#
# 0        Russell 2000 Growth        Russell 2000  Russell 1000  MSCI World  \
# 0        Russell 2000 Growth        Russell 2000  Russell 1000  MSCI World
# ...

# %% [markdown]
# ### Store benchmark data, removing all blank space and miscellaneous data at the top

# %%
bm_df = bm_df.iloc[9:]
bm_df.head()
# Out:
# 0             Shortname MSCI ACWI   S&P 500 BarCap US Agg BarCap High Yield  \
# 9   1988-01-31 00:00:00   0.02533  0.042061      0.035152          0.033446
# 10  1988-02-29 00:00:00  0.058079  0.046607       0.01187          0.032363
# 11  1988-03-31 00:00:00    0.0311 -0.030875     -0.009385         -0.010396
# 12  1988-04-30 00:00:00   0.01298  0.011066     -0.005396          0.007635
# 13  1988-05-31 00:00:00 -0.019521  0.008635     -0.006722          0.001505
#
# 0  BarCap Global Agg MSCI Emerging Markets Russell 2500 Index  \
# 9                NaN                   NaN                NaN
# 10               NaN                   NaN                NaN
# 11               NaN                   NaN                NaN
# 12               NaN                   NaN                NaN
# 13               NaN                   NaN                NaN
#
# 0  Russell 2000 Growth Russell 2000 Russell 1000 MSCI World MSCI EAFE  \
# ...

# %% [markdown]
# ### Rename 'shortname' to 'Date'

# %%
bm_df.rename(columns = {'Shortname':'Date'}, inplace=True)
bm_df.head()
# Out:
# 0                  Date MSCI ACWI   S&P 500 BarCap US Agg BarCap High Yield  \
# 9   1988-01-31 00:00:00   0.02533  0.042061      0.035152          0.033446
# 10  1988-02-29 00:00:00  0.058079  0.046607       0.01187          0.032363
# 11  1988-03-31 00:00:00    0.0311 -0.030875     -0.009385         -0.010396
# 12  1988-04-30 00:00:00   0.01298  0.011066     -0.005396          0.007635
# 13  1988-05-31 00:00:00 -0.019521  0.008635     -0.006722          0.001505
#
# 0  BarCap Global Agg MSCI Emerging Markets Russell 2500 Index  \
# 9                NaN                   NaN                NaN
# 10               NaN                   NaN                NaN
# 11               NaN                   NaN                NaN
# 12               NaN                   NaN                NaN
# 13               NaN                   NaN                NaN
#
# 0  Russell 2000 Growth Russell 2000 Russell 1000 MSCI World MSCI EAFE  \
# ...

# %% [markdown]
# ## Read Managers data

# %%
mgr_df = pd.read_excel(path, sheet_name='Managers')

# %%
mgr_df.head(10)
# Out:
#             Unnamed: 0           Unnamed: 1           Unnamed: 2
# 0            Shortname                    D                    L
# 1             Longname                  NaN                  NaN
# 2                 Code                  NaN                  NaN
# 3                 Type           UJA Hybrid           UJA Hybrid
# 4                  CCY                  USD                  USD
# 5            Benchmark            MSCI ACWI    HFRI Event Driven
# 6         UJAInception  2022-12-31 00:00:00  2019-09-30 00:00:00
# 7                blank                  NaN                  NaN
# 8                blank                  NaN                  NaN
# 9  1988-01-31 00:00:00                  NaN                  NaN

# %% [markdown]
# ### Store toprows for use later on

# %%
toprows_mgr_df  = mgr_df.iloc[:9]
toprows_mgr_df
# Out:
#      Unnamed: 0           Unnamed: 1           Unnamed: 2
# 0     Shortname                    D                    L
# 1      Longname                  NaN                  NaN
# 2          Code                  NaN                  NaN
# 3          Type           UJA Hybrid           UJA Hybrid
# 4           CCY                  USD                  USD
# 5     Benchmark            MSCI ACWI    HFRI Event Driven
# 6  UJAInception  2022-12-31 00:00:00  2019-09-30 00:00:00
# 7         blank                  NaN                  NaN
# 8         blank                  NaN                  NaN

# %% [markdown]
# ### Set manager names as column names

# %%
mgr_df.columns = mgr_df.iloc[0]
mgr_df.head()
# Out:
# 0  Shortname           D           L
# 0  Shortname           D           L
# 1   Longname         NaN         NaN
# 2       Code         NaN         NaN
# 3       Type  UJA Hybrid  UJA Hybrid
# 4        CCY         USD         USD

# %% [markdown]
# ### Store returns data, removing all blank space and miscellaneous data at the top

# %%
mgr_df  = mgr_df.iloc[9:]
mgr_df
# Out:
# 0              Shortname    D    L
# 9    1988-01-31 00:00:00  NaN  NaN
# 10   1988-02-29 00:00:00  NaN  NaN
# 11   1988-03-31 00:00:00  NaN  NaN
# 12   1988-04-30 00:00:00  NaN  NaN
# 13   1988-05-31 00:00:00  NaN  NaN
# ..                   ...  ...  ...
# 435  2023-07-31 00:00:00  NaN  NaN
# 436  2023-08-31 00:00:00  NaN  NaN
# 437  2023-09-30 00:00:00  NaN  NaN
# 438  2023-10-31 00:00:00  NaN  NaN
# 439  2023-11-30 00:00:00  NaN  NaN
#
# [431 rows x 3 columns]

# %% [markdown]
# ### Rename 'Shortname' to 'Date'

# %%
mgr_df.rename(columns = {'Shortname':'Date'}, inplace=True)
mgr_df.head()
# Out:
# 0                  Date    D    L
# 9   1988-01-31 00:00:00  NaN  NaN
# 10  1988-02-29 00:00:00  NaN  NaN
# 11  1988-03-31 00:00:00  NaN  NaN
# 12  1988-04-30 00:00:00  NaN  NaN
# 13  1988-05-31 00:00:00  NaN  NaN

# %% [markdown]
# ## First Portfolio Manager - Fund D

# %% [markdown]
# ### Narrow in on only those dates for which we have returns for the given portfolio manager

# %%
d_df = mgr_df[mgr_df['D'].isnull()==False]

# %% [markdown]
# ### Drop Fund L as this is focused on Fund D alone

# %%
d_df = d_df.drop(columns=['L'])

d_df.head()
# Out:
# 0                   Date       D
# 369  2018-01-31 00:00:00  0.0033
# 370  2018-02-28 00:00:00 -0.0105
# 371  2018-03-31 00:00:00 -0.0137
# 372  2018-04-30 00:00:00  0.0227
# 373  2018-05-31 00:00:00  0.0431

# %% [markdown]
# ### Remove all rows below the returns (like Return calculations, volatility and sharpe ratios) as these will be calculated later

# %%
bm_df = bm_df.iloc[:429]

# %%
bm_df
# Out:
# 0                   Date MSCI ACWI   S&P 500 BarCap US Agg BarCap High Yield  \
# 9    1988-01-31 00:00:00   0.02533  0.042061      0.035152          0.033446
# 10   1988-02-29 00:00:00  0.058079  0.046607       0.01187          0.032363
# 11   1988-03-31 00:00:00    0.0311 -0.030875     -0.009385         -0.010396
# 12   1988-04-30 00:00:00   0.01298  0.011066     -0.005396          0.007635
# 13   1988-05-31 00:00:00 -0.019521  0.008635     -0.006722          0.001505
# ..                   ...       ...       ...           ...               ...
# 433  2023-05-31 00:00:00       NaN       NaN           NaN               NaN
# 434  2023-06-30 00:00:00       NaN       NaN           NaN               NaN
# 435  2023-07-31 00:00:00       NaN       NaN           NaN               NaN
# 436  2023-08-31 00:00:00       NaN       NaN           NaN               NaN
# 437  2023-09-30 00:00:00       NaN       NaN           NaN               NaN
#
# ...

# %%
bm_df.shape
# Out:
# (429, 30)

# %%
d_df.shape
# Out:
# (61, 2)

# %%
bm_df = bm_df.drop_duplicates()
d_df = d_df.drop_duplicates()

# %%
bm_df.shape
# Out:
# (429, 30)

# %%
d_df.shape
# Out:
# (61, 2)

# %% [markdown]
# ### Combine benchmark data with portfolio manager D data on the relevant dates(lifespan of the portfolio manager)

# %%
d_comb_df = pd.merge(bm_df, d_df, on='Date')

# %%
d_comb_df
# Out:
# 0                  Date MSCI ACWI   S&P 500 BarCap US Agg BarCap High Yield  \
# 0   2018-01-31 00:00:00  0.056416  0.057254     -0.011518          0.005995
# 1   2018-02-28 00:00:00 -0.041998 -0.036856     -0.009477         -0.008498
# 2   2018-03-31 00:00:00 -0.021407 -0.025414      0.006413         -0.006041
# 3   2018-04-30 00:00:00   0.00955  0.003837     -0.007439          0.006507
# 4   2018-05-31 00:00:00  0.001248  0.024082      0.007135         -0.000278
# ..                  ...       ...       ...           ...               ...
# 56  2022-09-30 00:00:00 -0.095729   -0.0921     -0.043209         -0.039716
# 57  2022-10-31 00:00:00  0.060347  0.080961     -0.012953          0.025985
# 58  2022-11-30 00:00:00  0.077563  0.055885      0.036776          0.021704
# 59  2022-12-31 00:00:00 -0.039351 -0.057615     -0.004509         -0.006242
# 60  2023-01-31 00:00:00  0.071677  0.062834      0.030765          0.038074
#
# ...

# %% [markdown]
# ### Store all column names (All benchmarks and portfolio manager names)

# %%
col = d_comb_df.columns

# %% [markdown]
# ### Store numerical column names

# %%
num_col = col[1:]
num_col
# Out:
# Index(['MSCI ACWI', 'S&P 500', 'BarCap US Agg', 'BarCap High Yield',
#        'BarCap Global Agg', 'MSCI Emerging Markets', 'Russell 2500 Index',
#        'Russell 2000 Growth', 'Russell 2000', 'Russell 1000', 'MSCI World',
#        'MSCI EAFE', 'Russell 3000 Growth', 'MSCI EM Small', 'MSCI ACWI Small',
#        'MSCI ACWI Large', 'MSCI Asia Pacific', 'Barcap US MBS', 'MSCI China',
#        'Cash', 'Newedge Trend Index', 'CSI 300 TR USD', 'DJ MN Momentum',
#        'DJ MN Value', 'DJ MN Anti-Beta', 'DJ MN Quality', 'DJ MN Size',
#        'MSCI ACWI Value', 'Barclays US Covertible Bond Index', 'D'],
#       dtype='object', name=0)

# %% [markdown]
# ### Change datatype of date field from string to date and return columns from string to float

# %%
d_comb_df[num_col] = d_comb_df[num_col].astype('float')

# %%
d_comb_df['Date'] = pd.to_datetime(d_comb_df['Date'])

# %%
d_comb_df.columns
# Out:
# Index(['Date', 'MSCI ACWI', 'S&P 500', 'BarCap US Agg', 'BarCap High Yield',
#        'BarCap Global Agg', 'MSCI Emerging Markets', 'Russell 2500 Index',
#        'Russell 2000 Growth', 'Russell 2000', 'Russell 1000', 'MSCI World',
#        'MSCI EAFE', 'Russell 3000 Growth', 'MSCI EM Small', 'MSCI ACWI Small',
#        'MSCI ACWI Large', 'MSCI Asia Pacific', 'Barcap US MBS', 'MSCI China',
#        'Cash', 'Newedge Trend Index', 'CSI 300 TR USD', 'DJ MN Momentum',
#        'DJ MN Value', 'DJ MN Anti-Beta', 'DJ MN Quality', 'DJ MN Size',
#        'MSCI ACWI Value', 'Barclays US Covertible Bond Index', 'D'],
#       dtype='object', name=0)

# %% [markdown]
# ### Check correlation across all benchmarks

# %%
corr_cols = ['Date', 'MSCI ACWI', 'S&P 500', 'BarCap US Agg', 'BarCap High Yield',
'BarCap Global Agg', 'MSCI Emerging Markets', 'Russell 2500 Index',
'Russell 2000 Growth', 'Russell 2000', 'Russell 1000', 'MSCI World',
'MSCI EAFE', 'Russell 3000 Growth', 'MSCI EM Small', 'MSCI ACWI Small',
'MSCI ACWI Large', 'MSCI Asia Pacific', 'Barcap US MBS', 'MSCI China',
       'Cash', 'Newedge Trend Index', 'CSI 300 TR USD', 'DJ MN Momentum',
       'DJ MN Value', 'DJ MN Anti-Beta', 'DJ MN Quality', 'DJ MN Size',
       'MSCI ACWI Value', 'Barclays US Covertible Bond Index']

# %%
sns.heatmap(d_comb_df[corr_cols].corr())
# Out:
# <AxesSubplot:xlabel='0', ylabel='0'>

# %%
d_comb_df.shape
# Out:
# (61, 31)

# %% [markdown]
# ### Remove benchmarks which have correlation>0.9 with any other benchmark

# %%
corr_matrix = d_comb_df[corr_cols].corr().abs()

# %%
upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape),k=1).astype(np.bool))

to_drop = [column for column in upper_tri.columns if any(upper_tri[column] >= 0.90)]

d_new_df = d_comb_df.drop(to_drop, axis=1)
# Out:
# C:\Users\127ri\AppData\Local\Temp\ipykernel_1936\3067266215.py:1: DeprecationWarning:
#
# `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# ### This reduces our benchmarks from 29 originally, down to 13 benchmarks

# %%
d_new_df.shape
# Out:
# (61, 15)

# %%
d_new_df.columns
# Out:
# Index(['Date', 'MSCI ACWI', 'BarCap US Agg', 'BarCap High Yield',
#        'MSCI Emerging Markets', 'MSCI China', 'Cash', 'Newedge Trend Index',
#        'CSI 300 TR USD', 'DJ MN Momentum', 'DJ MN Value', 'DJ MN Anti-Beta',
#        'DJ MN Quality', 'DJ MN Size', 'D'],
#       dtype='object', name=0)

# %%
d_new_df.head()
# Out:
# 0       Date  MSCI ACWI  BarCap US Agg  BarCap High Yield  \
# 0 2018-01-31   0.056416      -0.011518           0.005995
# 1 2018-02-28  -0.041998      -0.009477          -0.008498
# 2 2018-03-31  -0.021407       0.006413          -0.006041
# 3 2018-04-30   0.009550      -0.007439           0.006507
# 4 2018-05-31   0.001248       0.007135          -0.000278
#
# 0  MSCI Emerging Markets  MSCI China      Cash  Newedge Trend Index  \
# 0               0.083347    0.124881  0.001099             0.058499
# 1              -0.046120   -0.064041  0.001077            -0.089566
# 2              -0.018593   -0.032914  0.001305            -0.002555
# 3              -0.004425   -0.000237  0.001349             0.004088
# 4              -0.035434    0.018366  0.001493            -0.027712
#
# 0  CSI 300 TR USD  DJ MN Momentum  DJ MN Value  DJ MN Anti-Beta  \
# 0        0.096577        0.039987    -0.008042        -0.022642
# 1       -0.063435        0.018738    -0.004982        -0.002441
# ...

# %%
reg_cols = d_new_df.columns

# %%
reg_cols
# Out:
# Index(['Date', 'MSCI ACWI', 'BarCap US Agg', 'BarCap High Yield',
#        'MSCI Emerging Markets', 'MSCI China', 'Cash', 'Newedge Trend Index',
#        'CSI 300 TR USD', 'DJ MN Momentum', 'DJ MN Value', 'DJ MN Anti-Beta',
#        'DJ MN Quality', 'DJ MN Size', 'D'],
#       dtype='object', name=0)

# %%
reg_cols = reg_cols[1:-1]

# %%
reg_cols
# Out:
# Index(['MSCI ACWI', 'BarCap US Agg', 'BarCap High Yield',
#        'MSCI Emerging Markets', 'MSCI China', 'Cash', 'Newedge Trend Index',
#        'CSI 300 TR USD', 'DJ MN Momentum', 'DJ MN Value', 'DJ MN Anti-Beta',
#        'DJ MN Quality', 'DJ MN Size'],
#       dtype='object', name=0)

# %%
for col in reg_cols:
    if col!='Cash':
        name=col+'_diff'
        d_new_df[name] = d_new_df[col] - d_new_df['Cash']
    else:
        continue

# %%
d_reg_cols = []

for col in d_new_df.columns:
    if 'diff' in col:
        d_reg_cols.append(col)

# %%
fig, ax = plt.subplots(4,3, figsize=(15,20))

for var, subplot in zip(d_reg_cols, ax.flatten()):
    sns.scatterplot(x=d_new_df[var], y=d_new_df['D_diff'], ax=subplot)
    #print(var, subplot)

# %% [markdown]
# ## Regression Analysis

# %% [markdown]
# ### Regression on monthly returns across all non-highly correlated benchmarks(including Cash/risk-free)

# %%
import statsmodels.api as sm

X = d_new_df[reg_cols]

for col in X.columns[X.isnull().any(axis=0)]:
    X[col] = X[col].fillna(X[col].mean())
    
X = sm.add_constant(X)

Y = d_new_df['D']

model_tca = sm.OLS(Y, X).fit()
model_tca.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      D   R-squared:                       0.775
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     12.46
# Date:                Sun, 16 Apr 2023   Prob (F-statistic):           3.80e-11
# Time:                        17:06:43   Log-Likelihood:                 139.97
# No. Observations:                  61   AIC:                            -251.9
# Df Residuals:                      47   BIC:                            -222.4
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Add new columns which calculate the excess returns(compared with Cash/Risk-free return)

# %%
d_new_df['D_diff'] = d_new_df['D'] - d_new_df['Cash']

# %%
d_new_df
# Out:
# 0        Date  MSCI ACWI  BarCap US Agg  BarCap High Yield  \
# 0  2018-01-31   0.056416      -0.011518           0.005995
# 1  2018-02-28  -0.041998      -0.009477          -0.008498
# 2  2018-03-31  -0.021407       0.006413          -0.006041
# 3  2018-04-30   0.009550      -0.007439           0.006507
# 4  2018-05-31   0.001248       0.007135          -0.000278
# ..        ...        ...            ...                ...
# 56 2022-09-30  -0.095729      -0.043209          -0.039716
# 57 2022-10-31   0.060347      -0.012953           0.025985
# 58 2022-11-30   0.077563       0.036776           0.021704
# 59 2022-12-31  -0.039351      -0.004509          -0.006242
# 60 2023-01-31   0.071677       0.030765           0.038074
#
# 0   MSCI Emerging Markets  MSCI China      Cash  Newedge Trend Index  \
# 0                0.083347    0.124881  0.001099             0.058499
# 1               -0.046120   -0.064041  0.001077            -0.089566
# ...

# %%
d_reg_cols
# Out:
# ['MSCI ACWI_diff',
#  'BarCap US Agg_diff',
#  'BarCap High Yield_diff',
#  'MSCI Emerging Markets_diff',
#  'MSCI China_diff',
#  'Newedge Trend Index_diff',
#  'CSI 300 TR USD_diff',
#  'DJ MN Momentum_diff',
#  'DJ MN Value_diff',
#  'DJ MN Anti-Beta_diff',
#  'DJ MN Quality_diff',
#  'DJ MN Size_diff']

# %% [markdown]
# ### Regression on monthly EXCESS returns across all non-highly correlated benchmarks

# %%
import statsmodels.api as sm

X = d_new_df[d_reg_cols]

for col in X.columns[X.isnull().any(axis=0)]:
    X[col] = X[col].fillna(X[col].mean())
    
X = sm.add_constant(X)

Y = d_new_df['D_diff']

model_tca = sm.OLS(Y, X).fit()
model_tca.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 D_diff   R-squared:                       0.775
# Model:                            OLS   Adj. R-squared:                  0.718
# Method:                 Least Squares   F-statistic:                     13.74
# Date:                Sun, 16 Apr 2023   Prob (F-statistic):           1.04e-11
# Time:                        17:06:44   Log-Likelihood:                 139.90
# No. Observations:                  61   AIC:                            -253.8
# Df Residuals:                      48   BIC:                            -226.4
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Observations
#     R-squared is the highest for these features.
#     However, almost all benchmarks are insignificant, only MSCI ACWI has high significance and with a BETA of 0.9 which suggests that manager is positively correlated with this benchmark. Among others, only DJTMN benches have significant Betas.
#     The Alpha is almost significant, which would suggest the manager is performing better than these funds but this is too many benchmarks to make any meaningful inference on the drivers of the manager's performance

# %% [markdown]
# ### Regression on MSCI ACWI benchmark alone as that has been indentified as benchmark on the Managers tab

# %%
import statsmodels.api as sm

X = d_new_df['MSCI ACWI_diff']

#for col in X.columns[X.isnull().any(axis=0)]:
#    X[col] = X[col].fillna(X[col].mean())
    
X = sm.add_constant(X)

Y = d_new_df['D_diff']

model_tca = sm.OLS(Y, X).fit()
model_tca.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 D_diff   R-squared:                       0.622
# Model:                            OLS   Adj. R-squared:                  0.616
# Method:                 Least Squares   F-statistic:                     97.14
# Date:                Sun, 16 Apr 2023   Prob (F-statistic):           4.42e-14
# Time:                        17:06:44   Log-Likelihood:                 124.14
# No. Observations:                  61   AIC:                            -244.3
# Df Residuals:                      59   BIC:                            -240.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Observations:
#     R-squared indicates this benchmark alone explain 62.2% of the variance, which is good but we need to check if it can be bettered.
#     The Alpha is firstly statistically insignificant(p value 0.366), which indicates that we cannot claim the portfolio manager D is providing a better return than the benchmark MSCI ACWI on a consistent basis.
#     In addition, not only is the Alpha insignificant, it is as also very small, at 0.38% which further indicates that manager does not seem to provide meaningfully better returns.
#     This MSCI ACWI benchmark is statistically significant, with a Beta of 0.795, it underperforms when the market does well and overperforms when the benchmark had poor returns.

# %% [markdown]
# ### Perform stepwise regression to identify 3 benchmarks that provide a better R-squared value to help narrow in on the drivers of the performance

# %%
from mlxtend.feature_selection import SequentialFeatureSelector

# %%
X = d_new_df[d_reg_cols]
X = sm.add_constant(X)

Y = d_new_df['D_diff']

sfs = SequentialFeatureSelector(LinearRegression(),
                                k_features=3,
                                forward=True)
selected_features = sfs.fit(X, Y)

# %%
selected_features.k_feature_names_
# Out:
# ('MSCI ACWI_diff', 'MSCI Emerging Markets_diff', 'DJ MN Quality_diff')

# %%
selected_features.get_params()
# Out:
# {'clone_estimator': True,
#  'cv': 5,
#  'estimator__copy_X': True,
#  'estimator__fit_intercept': True,
#  'estimator__n_jobs': None,
#  'estimator__normalize': 'deprecated',
#  'estimator__positive': False,
#  'estimator': LinearRegression(),
#  'feature_groups': None,
#  'fixed_features': None,
#  'floating': False,
#  'forward': True,
#  'k_features': (3, 3),
#  'n_jobs': 1,
#  'pre_dispatch': '2*n_jobs',
#  'scoring': 'r2',
#  'verbose': 0,
#  'linearregression': LinearRegression(),
#  'linearregression__copy_X': True,
#  'linearregression__fit_intercept': True,
#  'linearregression__n_jobs': None,
#  'linearregression__normalize': 'deprecated',
#  'linearregression__positive': False}

# %%
selected_features.get_metric_dict()
# Out:
# {1: {'feature_idx': (4,),
#   'cv_scores': array([ 0.37003287, -0.0942346 ,  0.62389479,  0.45260989,  0.62966284]),
#   'avg_score': 0.3963931578939946,
#   'feature_names': ('MSCI Emerging Markets_diff',),
#   'ci_bound': 0.34041653153599455,
#   'std_dev': 0.2648556266034286,
#   'std_err': 0.1324278133017143},
#  2: {'feature_idx': (4, 11),
#   'cv_scores': array([0.42933675, 0.28128239, 0.73964256, 0.40782292, 0.64513851]),
#   'avg_score': 0.5006446279074659,
#   'feature_names': ('MSCI Emerging Markets_diff', 'DJ MN Quality_diff'),
#   'ci_bound': 0.21493120877851724,
#   'std_dev': 0.167223782349264,
#   'std_err': 0.083611891174632},
#  3: {'feature_idx': (1, 4, 11),
#   'cv_scores': array([0.43789424, 0.3974065 , 0.83211334, 0.4468458 , 0.62869792]),
#   'avg_score': 0.5485915598038016,
#   'feature_names': ('MSCI ACWI_diff',
#    'MSCI Emerging Markets_diff',
#    'DJ MN Quality_diff'),
#   'ci_bound': 0.2090443000724704,
#   'std_dev': 0.1626435673783223,
# ...

# %% [markdown]
# ### The 3 identified benchmarks are :

# %%
selected_cols = ['MSCI ACWI_diff', 'MSCI Emerging Markets_diff', 'DJ MN Quality_diff']

# %% [markdown]
# ### Regression on these three benchmarks

# %%
import statsmodels.api as sm

X = d_new_df[selected_cols]

for col in X.columns[X.isnull().any(axis=0)]:
    X[col] = X[col].fillna(X[col].mean())
    
X = sm.add_constant(X)

Y = d_new_df['D_diff']

model_tca = sm.OLS(Y, X).fit()
model_tca.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 D_diff   R-squared:                       0.721
# Model:                            OLS   Adj. R-squared:                  0.706
# Method:                 Least Squares   F-statistic:                     49.03
# Date:                Sun, 16 Apr 2023   Prob (F-statistic):           8.52e-16
# Time:                        17:06:45   Log-Likelihood:                 133.36
# No. Observations:                  61   AIC:                            -258.7
# Df Residuals:                      57   BIC:                            -250.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Observations
#     R-squared is better at 72.1%, so the addition of these two other benchmarks better explains the portfolio manager performance.
#     The Alpha is still insignificant, indicating that we cannot say that the manager is providing better returns than the benchmarks
#     The manager is positiviely correlated with MSCI ACWI and MSCI Emerging Markets, and negatively correlated with DJ MN Quality

# %%
model_tca.predict(X)
# Out:
# 0     0.044449
# 1    -0.030400
# 2    -0.008124
# 3     0.013625
# 4    -0.003646
#         ...
# 56   -0.082666
# 57    0.021000
# 58    0.060105
# 59   -0.022683
# 60    0.072770
# Length: 61, dtype: float64

# %%
plot_d = pd.DataFrame()

# %%
#plot_d['Date'] = d_new_df['Date']

plot_d = d_new_df[selected_cols]

plot_d['Date'] = d_new_df['Date']

plot_d['D_diff'] = d_new_df['D_diff']

plot_d['Regression'] = model_tca.predict(X).values

# %%
plot_d
# Out:
# 0   MSCI ACWI_diff  MSCI Emerging Markets_diff  DJ MN Quality_diff       Date  \
# 0         0.055318                    0.082248            0.015534 2018-01-31
# 1        -0.043075                   -0.047197            0.007450 2018-02-28
# 2        -0.022712                   -0.019897           -0.003450 2018-03-31
# 3         0.008201                   -0.005774           -0.010413 2018-04-30
# 4        -0.000244                   -0.036926           -0.000309 2018-05-31
# ..             ...                         ...                 ...        ...
# 56       -0.097688                   -0.119191            0.023152 2022-09-30
# 57        0.057870                   -0.033524            0.006089 2022-10-31
# 58        0.074697                    0.145450            0.033639 2022-11-30
# 59       -0.042726                   -0.017430            0.007579 2022-12-31
# 60        0.067986                    0.075271           -0.030167 2023-01-31
#
# 0     D_diff  Regression
# ...

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
plt.rcParams.update({'font.size': 15})
plot_d.plot(x='Date', y=[col for col in plot_d.columns if col!='Date'], figsize=(20, 10), ax=ax, fontsize=16, ylabel='Returns')
plt.legend(title='Legend')
plt.rcParams["legend.loc"] = 'upper left'
for line in ax.get_lines():
    if line.get_label() == 'D_diff' or line.get_label() == 'Regression':
        line.set_linewidth(10)
    else:
        line.set_dashes([5,2])
plt.show()

# %%
selections = []

# %%
for n in range(2,10):
    
    X = d_new_df[d_reg_cols]
    X = sm.add_constant(X)
    
    Y = d_new_df['D_diff']
    
    sfs = SequentialFeatureSelector(LinearRegression(),
                                k_features=n,
                                forward=True)
    selected_features = sfs.fit(X, Y)
    print(list(selected_features.k_feature_names_))
    
    selections.append(list(selected_features.k_feature_names_))
    
    try:
        X = d_new_df[list(selected_features.k_feature_names_)]
        X = sm.add_constant(X)
    
        for col in X.columns[X.isnull().any(axis=0)]:
            X[col] = X[col].fillna(X[col].mean())

        model_tca = sm.OLS(Y, X).fit()
        print(model_tca.summary())
    except:
        continue
# Out:
# ['MSCI Emerging Markets_diff', 'DJ MN Quality_diff']
#                             OLS Regression Results
# ...
# Dep. Variable:                 D_diff   R-squared:                       0.652
# Model:                            OLS   Adj. R-squared:                  0.640
# Method:                 Least Squares   F-statistic:                     54.43
# Date:                Sat, 15 Apr 2023   Prob (F-statistic):           4.92e-14
# Time:                        21:27:50   Log-Likelihood:                 126.69
# No. Observations:                  61   AIC:                            -247.4
# Df Residuals:                      58   BIC:                            -241.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
ret_sel_cols = []

for col in selected_cols:
    ret_sel_cols.append(col.removesuffix('_diff'))

# %%
#ret_sel_cols.append('Cash')

ret_sel_cols
# Out:
# ['MSCI ACWI', 'MSCI Emerging Markets', 'DJ MN Quality']

# %%
d_sel_df = d_new_df[ret_sel_cols]
d_sel_df['D'] = d_new_df['D']

#d_sel_df[selected_cols] = d_new_df[selected_cols]
#d_sel_df['D_diff'] = d_new_df['D_diff']

# %%
d_sel_df
# Out:
# 0   MSCI ACWI  MSCI Emerging Markets  DJ MN Quality         D
# 0    0.056416               0.083347       0.016633  0.003300
# 1   -0.041998              -0.046120       0.008527 -0.010500
# 2   -0.021407              -0.018593      -0.002145 -0.013700
# 3    0.009550              -0.004425      -0.009065  0.022700
# 4    0.001248              -0.035434       0.001184  0.043100
# ..        ...                    ...            ...       ...
# 56  -0.095729              -0.117233       0.025111 -0.086500
# 57   0.060347              -0.031047       0.008566  0.052700
# 58   0.077563               0.148316       0.036505  0.085900
# 59  -0.039351              -0.014055       0.010953  0.029700
# 60   0.071677               0.078962      -0.026477  0.065748
#
# [61 rows x 4 columns]

# %%
am = d_sel_df.describe().iloc[1]

# %%
at = d_sel_df.sum()

# %%
from scipy import stats

# %%
gm = {}

# %%
for col in d_sel_df.columns:
    name = col+'_temp'
    d_sel_df[name] = d_sel_df[col]+1
    gm[col]=stats.gmean(d_sel_df.loc[:,name])-1

# %%
gm
# Out:
# {'MSCI ACWI': 0.00532501321850809,
#  'MSCI Emerging Markets': 9.345366734003768e-05,
#  'DJ MN Quality': 0.001292114450853532,
#  'D': 0.007941952899891191}

# %%
gm = pd.Series(gm)

gm
# Out:
# MSCI ACWI                0.005325
# MSCI Emerging Markets    0.000093
# DJ MN Quality            0.001292
# D                        0.007942
# dtype: float64

# %%
gt = np.exp(np.log(d_sel_df[[col for col in d_sel_df.columns if '_temp' in col]].prod(axis=0)))-1

# %%
gt.index = at.index

# %%
print(at)
print(am)
print(gt)
print(gm)
# Out:
# 0
# MSCI ACWI                0.404884
# MSCI Emerging Markets    0.096119
# DJ MN Quality            0.098943
# D                        0.565648
# dtype: float64
# 0
# MSCI ACWI                0.006637
# MSCI Emerging Markets    0.001576
# DJ MN Quality            0.001622
# D                        0.009273
# Name: mean, dtype: float64
# 0
# MSCI ACWI                0.382598
# MSCI Emerging Markets    0.005717
# DJ MN Quality            0.081953
# D                        0.620193
# dtype: float64
# MSCI ACWI                0.005325
# MSCI Emerging Markets    0.000093
# DJ MN Quality            0.001292
# D                        0.007942
# dtype: float64

# %%
return_measures = pd.DataFrame([at, am, gt, gm])

# %%
return_measures
# Out:
#            MSCI ACWI  MSCI Emerging Markets  DJ MN Quality         D
# Unnamed 0   0.404884               0.096119       0.098943  0.565648
# mean        0.006637               0.001576       0.001622  0.009273
# Unnamed 1   0.382598               0.005717       0.081953  0.620193
# Unnamed 2   0.005325               0.000093       0.001292  0.007942

# %%
new_index = ['Arithmetic Total', 'Arithmetic Mean', 'Geometric Total', 'Geometric Mean']

return_measures = return_measures.set_index(pd.Index(new_index))

return_measures
# Out:
#                   MSCI ACWI  MSCI Emerging Markets  DJ MN Quality         D
# Arithmetic Total   0.404884               0.096119       0.098943  0.565648
# Arithmetic Mean    0.006637               0.001576       0.001622  0.009273
# Geometric Total    0.382598               0.005717       0.081953  0.620193
# Geometric Mean     0.005325               0.000093       0.001292  0.007942

# %%
for col in return_measures.columns:
    if col!='D':
        name = 'D-'+col
        return_measures[name]= return_measures['D'] - return_measures[col]

# %%
return_measures
# Out:
#                   MSCI ACWI  MSCI Emerging Markets  DJ MN Quality         D  \
# Arithmetic Total   0.404884               0.096119       0.098943  0.565648
# Arithmetic Mean    0.006637               0.001576       0.001622  0.009273
# Geometric Total    0.382598               0.005717       0.081953  0.620193
# Geometric Mean     0.005325               0.000093       0.001292  0.007942
#
#                   D-MSCI ACWI  D-MSCI Emerging Markets  D-DJ MN Quality
# Arithmetic Total     0.160763                 0.469529         0.466705
# Arithmetic Mean      0.002635                 0.007697         0.007651
# Geometric Total      0.237596                 0.614477         0.538240
# Geometric Mean       0.002617                 0.007848         0.006650

# %%
for col in d_sel_df.columns:
    if '_temp' in col:
        d_sel_df.drop(columns = [col], inplace=True)

# %%
std_m = d_sel_df.describe().iloc[2]

# %%
std_a = std_m*np.sqrt(12)

# %%
std_a
# Out:
# 0
# MSCI ACWI                0.178114
# MSCI Emerging Markets    0.189979
# DJ MN Quality            0.090328
# D                        0.179655
# Name: std, dtype: float64

# %%
risk_measures = pd.DataFrame([std_m, std_a])

# %%
risk_measures
# Out:
# 0    MSCI ACWI  MSCI Emerging Markets  DJ MN Quality         D
# std   0.051417               0.054842       0.026075  0.051862
# std   0.178114               0.189979       0.090328  0.179655

# %%
new_index = ['Std Dev (Monthly)', 'Std Dev (Annually)']

risk_measures = risk_measures.set_index(pd.Index(new_index))

risk_measures
# Out:
# 0                   MSCI ACWI  MSCI Emerging Markets  DJ MN Quality         D
# Std Dev (Monthly)    0.051417               0.054842       0.026075  0.051862
# Std Dev (Annually)   0.178114               0.189979       0.090328  0.179655

# %%
for col in risk_measures.columns:
    if col!='D':
        name = 'D-'+col
        risk_measures[name]= risk_measures['D'] - risk_measures[col]

# %%
risk_measures
# Out:
# 0                   MSCI ACWI  MSCI Emerging Markets  DJ MN Quality         D  \
# Std Dev (Monthly)    0.051417               0.054842       0.026075  0.051862
# Std Dev (Annually)   0.178114               0.189979       0.090328  0.179655
#
# 0                   D-MSCI ACWI  D-MSCI Emerging Markets  D-DJ MN Quality
# Std Dev (Monthly)      0.000445                -0.002980         0.025786
# Std Dev (Annually)     0.001541                -0.010324         0.089327

# %%
mean_cash = d_new_df['Cash'].mean()

# %%
d_sharpe_df = pd.DataFrame([{'Row':1}])

# %%
d_sharpe_df
# Out:
#    Row
# 0    1

# %%
for col in return_measures.columns:
    if '-' not in col:
        #print(return_measures.loc['Arithmetic Mean', col])
        #print(risk_measures.loc['Std Dev (Monthly)',col])
        
        #print((return_measures.loc['Arithmetic Mean', col]-mean_cash)/risk_measures.loc['Std Dev (Monthly)',col])
        #print()
        d_sharpe_df[col] = ((return_measures.loc['Arithmetic Mean', col]-mean_cash)/risk_measures.loc['Std Dev (Monthly)',col])

# %%
d_sharpe_df = d_sharpe_df.drop(columns = ['Row'])

d_sharpe_df
# Out:
#    MSCI ACWI  MSCI Emerging Markets  DJ MN Quality         D
# 0   0.108165               0.009113       0.020942  0.158054

# %%
for col in d_sharpe_df.columns:
    if '-' not in col and 'D'!=col:
        name = 'D-'+col
        d_sharpe_df[name]= d_sharpe_df['D'] - d_sharpe_df[col]

# %%
d_sharpe_df
# Out:
#    MSCI ACWI  MSCI Emerging Markets  DJ MN Quality         D  D-MSCI ACWI  \
# 0   0.108165               0.009113       0.020942  0.158054     0.049889
#
#    D-MSCI Emerging Markets  D-DJ MN Quality
# 0                 0.148941         0.137111

# %% [markdown]
# ### Based on best performing benchmarks per stepwise regression

# %%
selected_cols = ['MSCI ACWI_diff', 'BarCap High Yield_diff', 'MSCI Emerging Markets_diff', 'DJ MN Anti-Beta_diff', 'DJ MN Quality_diff', 'DJ MN Size_diff']

# %% [markdown]
# ### Regression on these three benchmarks

# %%
import statsmodels.api as sm

X = d_new_df[selected_cols]

for col in X.columns[X.isnull().any(axis=0)]:
    X[col] = X[col].fillna(X[col].mean())
    
X = sm.add_constant(X)

Y = d_new_df['D_diff']

model_tca = sm.OLS(Y, X).fit()
model_tca.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 D_diff   R-squared:                       0.762
# Model:                            OLS   Adj. R-squared:                  0.735
# Method:                 Least Squares   F-statistic:                     28.79
# Date:                Sun, 16 Apr 2023   Prob (F-statistic):           3.61e-15
# Time:                        19:09:00   Log-Likelihood:                 138.22
# No. Observations:                  61   AIC:                            -262.4
# Df Residuals:                      54   BIC:                            -247.7
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Observations
#     Adjusted R-squared is highest at 73.5%, so the addition of these other benchmarks better explains the portfolio manager performance.
#     The Alpha is almost insignificant, and is positive suggesting the manager has performed better than the benchmarks but only by a small amount.

# %%
model_tca.predict(X)
# Out:
# 0     0.038140
# 1    -0.046240
# 2     0.006591
# 3     0.014993
# 4     0.004412
#         ...
# 56   -0.085250
# 57    0.036928
# 58    0.061503
# 59   -0.019842
# 60    0.059600
# Length: 61, dtype: float64

# %%
plot_d = pd.DataFrame()

# %%
#plot_d['Date'] = d_new_df['Date']

plot_d = d_new_df[selected_cols]

plot_d['Date'] = d_new_df['Date']

plot_d['D_diff'] = d_new_df['D_diff']

plot_d['Regression'] = model_tca.predict(X).values

# %%
plot_d
# Out:
# 0   MSCI ACWI_diff  BarCap High Yield_diff  MSCI Emerging Markets_diff  \
# 0         0.055318                0.004896                    0.082248
# 1        -0.043075               -0.009575                   -0.047197
# 2        -0.022712               -0.007346                   -0.019897
# 3         0.008201                0.005158                   -0.005774
# 4        -0.000244               -0.001770                   -0.036926
# ..             ...                     ...                         ...
# 56       -0.097688               -0.041674                   -0.119191
# 57        0.057870                0.023508                   -0.033524
# 58        0.074697                0.018838                    0.145450
# 59       -0.042726               -0.009616                   -0.017430
# 60        0.067986                0.034383                    0.075271
#
# 0   DJ MN Anti-Beta_diff  DJ MN Quality_diff  DJ MN Size_diff       Date  \
# ...

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
plt.rcParams.update({'font.size': 15})
plot_d.plot(x='Date', y=[col for col in plot_d.columns if col!='Date'], figsize=(20, 10), ax=ax, fontsize=16, ylabel='Returns')
plt.legend(title='Legend')
plt.rcParams["legend.loc"] = 'upper left'
for line in ax.get_lines():
    if line.get_label() == 'D_diff' or line.get_label() == 'Regression':
        line.set_linewidth(10)
    else:
        line.set_dashes([5,2])
plt.show()

# %% [markdown]
# ### Calculate Return and Risk Measures

# %%
ret_sel_cols = []

for col in selected_cols:
    ret_sel_cols.append(col.removesuffix('_diff'))

# %%
#ret_sel_cols.append('Cash')

ret_sel_cols
# Out:
# ['MSCI ACWI',
#  'BarCap High Yield',
#  'MSCI Emerging Markets',
#  'DJ MN Anti-Beta',
#  'DJ MN Quality',
#  'DJ MN Size']

# %%
d_sel_df = d_new_df[ret_sel_cols]
d_sel_df['D'] = d_new_df['D']

#d_sel_df[selected_cols] = d_new_df[selected_cols]
#d_sel_df['D_diff'] = d_new_df['D_diff']

# %%
d_sel_df
# Out:
# 0   MSCI ACWI  BarCap High Yield  MSCI Emerging Markets  DJ MN Anti-Beta  \
# 0    0.056416           0.005995               0.083347        -0.022642
# 1   -0.041998          -0.008498              -0.046120        -0.002441
# 2   -0.021407          -0.006041              -0.018593         0.029472
# 3    0.009550           0.006507              -0.004425         0.004839
# 4    0.001248          -0.000278              -0.035434        -0.006716
# ..        ...                ...                    ...              ...
# 56  -0.095729          -0.039716              -0.117233         0.033690
# 57   0.060347           0.025985              -0.031047         0.021088
# 58   0.077563           0.021704               0.148316        -0.005814
# 59  -0.039351          -0.006242              -0.014055         0.045554
# 60   0.071677           0.038074               0.078962        -0.103260
#
# 0   DJ MN Quality  DJ MN Size         D
# 0        0.016633   -0.034112  0.003300
# ...

# %%
am = d_sel_df.describe().iloc[1]

# %%
at = d_sel_df.sum()

# %%
from scipy import stats

# %%
gm = {}

# %%
for col in d_sel_df.columns:
    name = col+'_temp'
    d_sel_df[name] = d_sel_df[col]+1
    gm[col]=stats.gmean(d_sel_df.loc[:,name])-1

# %%
gm
# Out:
# {'MSCI ACWI': 0.00532501321850809,
#  'BarCap High Yield': 0.0024889907566718605,
#  'MSCI Emerging Markets': 9.345366734003768e-05,
#  'DJ MN Anti-Beta': 0.00023163720035657143,
#  'DJ MN Quality': 0.001292114450853532,
#  'DJ MN Size': -0.0031709650298676895,
#  'D': 0.007941952899891191}

# %%
gm = pd.Series(gm)

gm
# Out:
# MSCI ACWI                0.005325
# BarCap High Yield        0.002489
# MSCI Emerging Markets    0.000093
# DJ MN Anti-Beta          0.000232
# DJ MN Quality            0.001292
# DJ MN Size              -0.003171
# D                        0.007942
# dtype: float64

# %%
gt = np.exp(np.log(d_sel_df[[col for col in d_sel_df.columns if '_temp' in col]].prod(axis=0)))-1

# %%
gt.index = at.index

# %%
print(at)
print(am)
print(gt)
print(gm)
# Out:
# 0
# MSCI ACWI                0.404884
# BarCap High Yield        0.173364
# MSCI Emerging Markets    0.096119
# DJ MN Anti-Beta          0.074499
# DJ MN Quality            0.098943
# DJ MN Size              -0.172363
# D                        0.565648
# dtype: float64
# 0
# MSCI ACWI                0.006637
# BarCap High Yield        0.002842
# MSCI Emerging Markets    0.001576
# DJ MN Anti-Beta          0.001221
# DJ MN Quality            0.001622
# DJ MN Size              -0.002826
# D                        0.009273
# Name: mean, dtype: float64
# 0
# MSCI ACWI                0.382598
# BarCap High Yield        0.163741
# MSCI Emerging Markets    0.005717
# DJ MN Anti-Beta          0.014229
# DJ MN Quality            0.081953
# DJ MN Size              -0.176125
# D                        0.620193
# dtype: float64
# MSCI ACWI                0.005325
# BarCap High Yield        0.002489
# MSCI Emerging Markets    0.000093
# DJ MN Anti-Beta          0.000232
# ...

# %%
return_measures = pd.DataFrame([at, am, gt, gm])

# %%
return_measures
# Out:
#            MSCI ACWI  BarCap High Yield  MSCI Emerging Markets  \
# Unnamed 0   0.404884           0.173364               0.096119
# mean        0.006637           0.002842               0.001576
# Unnamed 1   0.382598           0.163741               0.005717
# Unnamed 2   0.005325           0.002489               0.000093
#
#            DJ MN Anti-Beta  DJ MN Quality  DJ MN Size         D
# Unnamed 0         0.074499       0.098943   -0.172363  0.565648
# mean              0.001221       0.001622   -0.002826  0.009273
# Unnamed 1         0.014229       0.081953   -0.176125  0.620193
# Unnamed 2         0.000232       0.001292   -0.003171  0.007942

# %%
new_index = ['Arithmetic Total', 'Arithmetic Mean', 'Geometric Total', 'Geometric Mean']

return_measures = return_measures.set_index(pd.Index(new_index))

return_measures
# Out:
#                   MSCI ACWI  BarCap High Yield  MSCI Emerging Markets  \
# Arithmetic Total   0.404884           0.173364               0.096119
# Arithmetic Mean    0.006637           0.002842               0.001576
# Geometric Total    0.382598           0.163741               0.005717
# Geometric Mean     0.005325           0.002489               0.000093
#
#                   DJ MN Anti-Beta  DJ MN Quality  DJ MN Size         D
# Arithmetic Total         0.074499       0.098943   -0.172363  0.565648
# Arithmetic Mean          0.001221       0.001622   -0.002826  0.009273
# Geometric Total          0.014229       0.081953   -0.176125  0.620193
# Geometric Mean           0.000232       0.001292   -0.003171  0.007942

# %%
for col in return_measures.columns:
    if col!='D':
        name = 'D-'+col
        return_measures[name]= return_measures['D'] - return_measures[col]

# %%
return_measures
# Out:
#                   MSCI ACWI  BarCap High Yield  MSCI Emerging Markets  \
# Arithmetic Total   0.404884           0.173364               0.096119
# Arithmetic Mean    0.006637           0.002842               0.001576
# Geometric Total    0.382598           0.163741               0.005717
# Geometric Mean     0.005325           0.002489               0.000093
#
#                   DJ MN Anti-Beta  DJ MN Quality  DJ MN Size         D  \
# Arithmetic Total         0.074499       0.098943   -0.172363  0.565648
# Arithmetic Mean          0.001221       0.001622   -0.002826  0.009273
# Geometric Total          0.014229       0.081953   -0.176125  0.620193
# Geometric Mean           0.000232       0.001292   -0.003171  0.007942
#
#                   D-MSCI ACWI  D-BarCap High Yield  D-MSCI Emerging Markets  \
# Arithmetic Total     0.160763             0.392284                 0.469529
# Arithmetic Mean      0.002635             0.006431                 0.007697
# ...

# %%
for col in d_sel_df.columns:
    if '_temp' in col:
        d_sel_df.drop(columns = [col], inplace=True)

# %%
std_m = d_sel_df.describe().iloc[2]

# %%
std_a = std_m*np.sqrt(12)

# %%
std_a
# Out:
# 0
# MSCI ACWI                0.178114
# BarCap High Yield        0.091683
# MSCI Emerging Markets    0.189979
# DJ MN Anti-Beta          0.153574
# DJ MN Quality            0.090328
# DJ MN Size               0.091171
# D                        0.179655
# Name: std, dtype: float64

# %%
risk_measures = pd.DataFrame([std_m, std_a])

# %%
risk_measures
# Out:
# 0    MSCI ACWI  BarCap High Yield  MSCI Emerging Markets  DJ MN Anti-Beta  \
# std   0.051417           0.026467               0.054842         0.044333
# std   0.178114           0.091683               0.189979         0.153574
#
# 0    DJ MN Quality  DJ MN Size         D
# std       0.026075    0.026319  0.051862
# std       0.090328    0.091171  0.179655

# %%
new_index = ['Std Dev (Monthly)', 'Std Dev (Annually)']

risk_measures = risk_measures.set_index(pd.Index(new_index))

risk_measures
# Out:
# 0                   MSCI ACWI  BarCap High Yield  MSCI Emerging Markets  \
# Std Dev (Monthly)    0.051417           0.026467               0.054842
# Std Dev (Annually)   0.178114           0.091683               0.189979
#
# 0                   DJ MN Anti-Beta  DJ MN Quality  DJ MN Size         D
# Std Dev (Monthly)          0.044333       0.026075    0.026319  0.051862
# Std Dev (Annually)         0.153574       0.090328    0.091171  0.179655

# %%
for col in risk_measures.columns:
    if col!='D':
        name = 'D-'+col
        risk_measures[name]= risk_measures['D'] - risk_measures[col]

# %%
risk_measures
# Out:
# 0                   MSCI ACWI  BarCap High Yield  MSCI Emerging Markets  \
# Std Dev (Monthly)    0.051417           0.026467               0.054842
# Std Dev (Annually)   0.178114           0.091683               0.189979
#
# 0                   DJ MN Anti-Beta  DJ MN Quality  DJ MN Size         D  \
# Std Dev (Monthly)          0.044333       0.026075    0.026319  0.051862
# Std Dev (Annually)         0.153574       0.090328    0.091171  0.179655
#
# 0                   D-MSCI ACWI  D-BarCap High Yield  D-MSCI Emerging Markets  \
# Std Dev (Monthly)      0.000445             0.025395                -0.002980
# Std Dev (Annually)     0.001541             0.087972                -0.010324
#
# 0                   D-DJ MN Anti-Beta  D-DJ MN Quality  D-DJ MN Size
# Std Dev (Monthly)            0.007529         0.025786      0.025543
# Std Dev (Annually)           0.026081         0.089327      0.088484

# %%
mean_cash = d_new_df['Cash'].mean()

# %%
d_sharpe_df = pd.DataFrame([{'Row':1}])

# %%
d_sharpe_df
# Out:
#    Row
# 0    1

# %%
for col in return_measures.columns:
    if '-' not in col:
        #print(return_measures.loc['Arithmetic Mean', col])
        #print(risk_measures.loc['Std Dev (Monthly)',col])
        
        #print((return_measures.loc['Arithmetic Mean', col]-mean_cash)/risk_measures.loc['Std Dev (Monthly)',col])
        #print()
        d_sharpe_df[col] = ((return_measures.loc['Arithmetic Mean', col]-mean_cash)/risk_measures.loc['Std Dev (Monthly)',col])

# %%
d_sharpe_df = d_sharpe_df.drop(columns = ['Row'])

d_sharpe_df
# Out:
#    MSCI ACWI  BarCap High Yield  MSCI Emerging Markets  DJ MN Quality  \
# 0   0.108165           0.066729               0.009113       0.020942
#
#    DJ MN Size         D
# 0   -0.148242  0.158054

# %%
for col in d_sharpe_df.columns:
    if '-' not in col and 'D'!=col:
        name = 'D-'+col
        d_sharpe_df[name]= d_sharpe_df['D'] - d_sharpe_df[col]

# %%
d_sharpe_df
# Out:
#    MSCI ACWI  BarCap High Yield  MSCI Emerging Markets  DJ MN Quality  \
# 0   0.108165           0.066729               0.009113       0.020942
#
#    DJ MN Size         D  D-MSCI ACWI  D-BarCap High Yield  \
# 0   -0.148242  0.158054     0.049889             0.091324
#
#    D-MSCI Emerging Markets  D-DJ MN Quality  D-DJ MN Size
# 0                 0.148941         0.137111      0.306296

# %%
fig, ax = plt.subplots(4,3, figsize=(15,15))

for var, subplot in zip(d_reg_cols, ax.flatten()):
    sns.scatterplot(x=d_new_df[var], y=d_new_df['D_diff'], ax=subplot)
    #print(var, subplot)

# %% [markdown]
# ## Second Portfolio Manager: Fund L

# %% [markdown]
# ### Narrow in on only those dates for which we have returns for the given portfolio manager

# %%
l_df = mgr_df[mgr_df['L'].isnull()==False]

# %% [markdown]
# ### Drop Fund Manager as focusing on Manager L now

# %%
l_df = l_df.drop(columns=['D'])

l_df.head()
# Out:
# 0                   Date      L
# 374  2018-06-30 00:00:00 -0.001
# 375  2018-07-31 00:00:00 -0.001
# 376  2018-08-31 00:00:00  0.022
# 377  2018-09-30 00:00:00      0
# 378  2018-10-31 00:00:00      0

# %%
bm_df.shape
# Out:
# (429, 30)

# %%
d_df.shape
# Out:
# (61, 2)

# %%
bm_df = bm_df.drop_duplicates()
d_df = d_df.drop_duplicates()

# %%
bm_df.shape
# Out:
# (429, 30)

# %%
d_df.shape
# Out:
# (61, 2)

# %% [markdown]
# ### Combine benchmark data with portfolio manager L data on the relevant dates(lifespan of the portfolio manager)

# %%
l_comb_df = pd.merge(bm_df, l_df, on='Date')

# %%
l_comb_df
# Out:
# 0                  Date MSCI ACWI   S&P 500 BarCap US Agg BarCap High Yield  \
# 0   2018-06-30 00:00:00 -0.005415  0.006154      -0.00123          0.004015
# 1   2018-07-31 00:00:00  0.030156  0.037215      0.000238          0.010911
# 2   2018-08-31 00:00:00  0.007857  0.032584      0.006436          0.007374
# 3   2018-09-30 00:00:00  0.004352  0.005692     -0.006439          0.005571
# 4   2018-10-31 00:00:00 -0.074939  -0.06835     -0.007901         -0.015985
# ..                  ...       ...       ...           ...               ...
# 51  2022-09-30 00:00:00 -0.095729   -0.0921     -0.043209         -0.039716
# 52  2022-10-31 00:00:00  0.060347  0.080961     -0.012953          0.025985
# 53  2022-11-30 00:00:00  0.077563  0.055885      0.036776          0.021704
# 54  2022-12-31 00:00:00 -0.039351 -0.057615     -0.004509         -0.006242
# 55  2023-01-31 00:00:00  0.071677  0.062834      0.030765          0.038074
#
# ...

# %% [markdown]
# ### Store all columns (all benchmarks and Manager L returns)

# %%
col = l_comb_df.columns

# %% [markdown]
# ### Store numerica columns

# %%
num_col = col[1:]
num_col
# Out:
# Index(['MSCI ACWI', 'S&P 500', 'BarCap US Agg', 'BarCap High Yield',
#        'BarCap Global Agg', 'MSCI Emerging Markets', 'Russell 2500 Index',
#        'Russell 2000 Growth', 'Russell 2000', 'Russell 1000', 'MSCI World',
#        'MSCI EAFE', 'Russell 3000 Growth', 'MSCI EM Small', 'MSCI ACWI Small',
#        'MSCI ACWI Large', 'MSCI Asia Pacific', 'Barcap US MBS', 'MSCI China',
#        'Cash', 'Newedge Trend Index', 'CSI 300 TR USD', 'DJ MN Momentum',
#        'DJ MN Value', 'DJ MN Anti-Beta', 'DJ MN Quality', 'DJ MN Size',
#        'MSCI ACWI Value', 'Barclays US Covertible Bond Index', 'L'],
#       dtype='object', name=0)

# %% [markdown]
# ### Change datatype of date from string to date and all returns from string to float

# %%
l_comb_df[num_col] = l_comb_df[num_col].astype('float')

# %%
l_comb_df['Date'] = pd.to_datetime(l_comb_df['Date'])

# %%
corr_cols = l_comb_df.columns[1:-1]

# %% [markdown]
# ### Plot Correlation of all benchmarks

# %%
sns.heatmap(l_comb_df[corr_cols].corr())
# Out:
# <AxesSubplot:xlabel='0', ylabel='0'>

# %%
l_comb_df.shape
# Out:
# (56, 31)

# %%
l_temp = l_comb_df.copy()

# %%
#l_context_df = l_comb_df.copy()

# %% [markdown]
# ### Remove all benchmarks which have a correlation >0.9 to any of the other benchmarks

# %%
corr_matrix = l_comb_df[corr_cols].corr().abs()

# %%
upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape),k=1).astype(np.bool))

to_drop = [column for column in upper_tri.columns if any(upper_tri[column] >= 0.90)]

l_new_df = l_comb_df.drop(to_drop, axis=1)
# Out:
# C:\Users\127ri\AppData\Local\Temp\ipykernel_1936\42538572.py:1: DeprecationWarning:
#
# `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
l_new_df.shape
# Out:
# (56, 15)

# %%
l_new_df.columns
# Out:
# Index(['Date', 'MSCI ACWI', 'BarCap US Agg', 'BarCap High Yield',
#        'MSCI Emerging Markets', 'MSCI China', 'Cash', 'Newedge Trend Index',
#        'CSI 300 TR USD', 'DJ MN Momentum', 'DJ MN Value', 'DJ MN Anti-Beta',
#        'DJ MN Quality', 'DJ MN Size', 'L'],
#       dtype='object', name=0)

# %%
l_new_df.head()
# Out:
# 0       Date  MSCI ACWI  BarCap US Agg  BarCap High Yield  \
# 0 2018-06-30  -0.005415      -0.001230           0.004015
# 1 2018-07-31   0.030156       0.000238           0.010911
# 2 2018-08-31   0.007857       0.006436           0.007374
# 3 2018-09-30   0.004352      -0.006439           0.005571
# 4 2018-10-31  -0.074939      -0.007901          -0.015985
#
# 0  MSCI Emerging Markets  MSCI China      Cash  Newedge Trend Index  \
# 0              -0.041548   -0.052200  0.001513             0.010614
# 1               0.021968   -0.024943  0.001622            -0.008132
# 2              -0.027040   -0.037962  0.001686             0.039261
# 3              -0.005306   -0.013990  0.001684            -0.009659
# 4              -0.087084   -0.114693  0.001820            -0.042942
#
# 0  CSI 300 TR USD  DJ MN Momentum  DJ MN Value  DJ MN Anti-Beta  \
# 0       -0.100964       -0.043122    -0.016514         0.038899
# 1       -0.021269       -0.001990     0.022121        -0.008811
# ...

# %%
reg_cols = l_new_df.columns

# %%
reg_cols = reg_cols[1:-1]

# %%
reg_cols
# Out:
# Index(['MSCI ACWI', 'BarCap US Agg', 'BarCap High Yield',
#        'MSCI Emerging Markets', 'MSCI China', 'Cash', 'Newedge Trend Index',
#        'CSI 300 TR USD', 'DJ MN Momentum', 'DJ MN Value', 'DJ MN Anti-Beta',
#        'DJ MN Quality', 'DJ MN Size'],
#       dtype='object', name=0)

# %% [markdown]
# ### Add new columns which calculate the fund's excess against Cash/risk-free returns

# %%
for col in reg_cols:
    if col!='Cash':
        name=col+'_diff'
        l_new_df[name] = l_new_df[col] - l_new_df['Cash']
    else:
        continue

# %%
l_reg_cols = []

for col in l_new_df.columns:
    if 'diff' in col:
        l_reg_cols.append(col)

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Regression on all benchmarks which are non-highly correlated(including Cash/Risk-free returns)

# %%
import statsmodels.api as sm

X = l_new_df[reg_cols]

for col in X.columns[X.isnull().any(axis=0)]:
    X[col] = X[col].fillna(X[col].mean())
    
# X = sm.add_constant(X)

Y = l_new_df['L']

model_tca = sm.OLS(Y, X).fit()
model_tca.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      L   R-squared (uncentered):                   0.169
# Model:                            OLS   Adj. R-squared (uncentered):             -0.082
# Method:                 Least Squares   F-statistic:                             0.6749
# Date:                Sun, 16 Apr 2023   Prob (F-statistic):                       0.776
# Time:                        23:09:06   Log-Likelihood:                          48.151
# No. Observations:                  56   AIC:                                     -70.30
# Df Residuals:                      43   BIC:                                     -43.97
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# ### Calculating the difference in returns of manager L against Cash/Risk-free return

# %%
l_new_df['L_diff'] = l_new_df['L'] - l_new_df['Cash']

# %%
l_new_df
# Out:
# 0        Date  MSCI ACWI  BarCap US Agg  BarCap High Yield  \
# 0  2018-06-30  -0.005415      -0.001230           0.004015
# 1  2018-07-31   0.030156       0.000238           0.010911
# 2  2018-08-31   0.007857       0.006436           0.007374
# 3  2018-09-30   0.004352      -0.006439           0.005571
# 4  2018-10-31  -0.074939      -0.007901          -0.015985
# ..        ...        ...            ...                ...
# 51 2022-09-30  -0.095729      -0.043209          -0.039716
# 52 2022-10-31   0.060347      -0.012953           0.025985
# 53 2022-11-30   0.077563       0.036776           0.021704
# 54 2022-12-31  -0.039351      -0.004509          -0.006242
# 55 2023-01-31   0.071677       0.030765           0.038074
#
# 0   MSCI Emerging Markets  MSCI China      Cash  Newedge Trend Index  \
# 0               -0.041548   -0.052200  0.001513             0.010614
# 1                0.021968   -0.024943  0.001622            -0.008132
# ...

# %% [markdown]
# ### Regression on the EXCESS returns of all non-highly correlated benchmarks including the outlier datapoint (-80%)

# %%
import statsmodels.api as sm

X = l_new_df[l_reg_cols]

for col in X.columns[X.isnull().any(axis=0)]:
    X[col] = X[col].fillna(X[col].mean())
    
# X = sm.add_constant(X)

Y = l_new_df['L_diff']

model_tca = sm.OLS(Y, X).fit()
model_tca.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 L_diff   R-squared (uncentered):                   0.152
# Model:                            OLS   Adj. R-squared (uncentered):             -0.079
# Method:                 Least Squares   F-statistic:                             0.6578
# Date:                Sun, 16 Apr 2023   Prob (F-statistic):                       0.781
# Time:                        23:09:07   Log-Likelihood:                          47.471
# No. Observations:                  56   AIC:                                     -70.94
# Df Residuals:                      44   BIC:                                     -46.64
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# ### Scatterplot of all benchmarks against the fund manager L returns

# %%
fig, ax = plt.subplots(4,3, figsize=(15,15))

for var, subplot in zip(l_reg_cols, ax.flatten()):
    sns.scatterplot(x=l_new_df[var], y=l_new_df['L_diff'], ax=subplot)
    #print(var, subplot)

# %% [markdown]
# ### Observation
#     Does not seem to have linear relation with the dependent variable

# %% [markdown]
# ### Should we remove the one month which had a very negative performance?

# %%
np.where(l_new_df['L_diff']<-0.7)
# Out:
# (array([5], dtype=int64),)

# %%
l_new_df.drop(index=l_new_df.iloc[5].name)
# Out:
# 0        Date  MSCI ACWI  BarCap US Agg  BarCap High Yield  \
# 0  2018-06-30  -0.005415      -0.001230           0.004015
# 1  2018-07-31   0.030156       0.000238           0.010911
# 2  2018-08-31   0.007857       0.006436           0.007374
# 3  2018-09-30   0.004352      -0.006439           0.005571
# 4  2018-10-31  -0.074939      -0.007901          -0.015985
# ..        ...        ...            ...                ...
# 51 2022-09-30  -0.095729      -0.043209          -0.039716
# 52 2022-10-31   0.060347      -0.012953           0.025985
# 53 2022-11-30   0.077563       0.036776           0.021704
# 54 2022-12-31  -0.039351      -0.004509          -0.006242
# 55 2023-01-31   0.071677       0.030765           0.038074
#
# 0   MSCI Emerging Markets  MSCI China      Cash  Newedge Trend Index  \
# 0               -0.041548   -0.052200  0.001513             0.010614
# 1                0.021968   -0.024943  0.001622            -0.008132
# ...

# %%
l_new_df = l_new_df.drop(index=l_new_df.iloc[5].name)

# %%
np.where(l_new_df['L_diff']<-0.7)
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# ### Plot all benchmarks against the portfolio manager L

# %%
fig, ax = plt.subplots(4,3, figsize=(15,15))

for var, subplot in zip(l_reg_cols, ax.flatten()):
    sns.scatterplot(x=l_new_df[var], y=l_new_df['L_diff'], ax=subplot)
    #print(var, subplot)

# %% [markdown]
# ### Regression on the EXCESS returns of the non-highly correlated benchmarks after removing outlier datapoint

# %%
import statsmodels.api as sm

X = l_new_df[l_reg_cols]

for col in X.columns[X.isnull().any(axis=0)]:
    X[col] = X[col].fillna(X[col].mean())
    
# X = sm.add_constant(X)

Y = l_new_df['L_diff']

model_tca = sm.OLS(Y, X).fit()
model_tca.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 L_diff   R-squared (uncentered):                   0.521
# Model:                            OLS   Adj. R-squared (uncentered):              0.388
# Method:                 Least Squares   F-statistic:                              3.901
# Date:                Sun, 16 Apr 2023   Prob (F-statistic):                    0.000461
# Time:                        23:09:15   Log-Likelihood:                          126.85
# No. Observations:                  55   AIC:                                     -229.7
# Df Residuals:                      43   BIC:                                     -205.6
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# ### Observations
#     Improved R-squared indicates the regression is better able to extimate the data on removing the large outlier

# %%
l_new_df
# Out:
# 0        Date  MSCI ACWI  BarCap US Agg  BarCap High Yield  \
# 0  2018-06-30  -0.005415      -0.001230           0.004015
# 1  2018-07-31   0.030156       0.000238           0.010911
# 2  2018-08-31   0.007857       0.006436           0.007374
# 3  2018-09-30   0.004352      -0.006439           0.005571
# 4  2018-10-31  -0.074939      -0.007901          -0.015985
# ..        ...        ...            ...                ...
# 51 2022-09-30  -0.095729      -0.043209          -0.039716
# 52 2022-10-31   0.060347      -0.012953           0.025985
# 53 2022-11-30   0.077563       0.036776           0.021704
# 54 2022-12-31  -0.039351      -0.004509          -0.006242
# 55 2023-01-31   0.071677       0.030765           0.038074
#
# 0   MSCI Emerging Markets  MSCI China      Cash  Newedge Trend Index  \
# 0               -0.041548   -0.052200  0.001513             0.010614
# 1                0.021968   -0.024943  0.001622            -0.008132
# ...

# %% [markdown]
# ### Given HFRI Event Driven benchmark is not present in the data and the instructions dictate that the Manager L invests primarily in convertible bonds, using the Barclays US Convertible Bond index as a first gauge of performance

# %%
reg_cols = l_comb_df.columns

# %%
reg_cols = reg_cols[1:]

# %% [markdown]
# ### Add new columns which calculate the fund's excess against Cash/risk-free returns

# %%
for col in reg_cols:
    if col!='Cash':
        name=col+'_diff'
        l_comb_df[name] = l_comb_df[col] - l_comb_df['Cash']
    else:
        continue

# %%
l_context_df = l_comb_df.copy()

# %%
l_context_df = l_context_df.drop(index=l_context_df.iloc[5].name)

# %%
import statsmodels.api as sm

X = l_context_df['Barclays US Covertible Bond Index_diff']

#for col in X.columns[X.isnull().any(axis=0)]:
#    X[col] = X[col].fillna(X[col].mean())
    
X = sm.add_constant(X)

Y = l_context_df['L_diff']

model_tca = sm.OLS(Y, X).fit()
model_tca.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 L_diff   R-squared:                       0.344
# Model:                            OLS   Adj. R-squared:                  0.332
# Method:                 Least Squares   F-statistic:                     27.83
# Date:                Sun, 16 Apr 2023   Prob (F-statistic):           2.50e-06
# Time:                        23:09:17   Log-Likelihood:                 119.02
# No. Observations:                  55   AIC:                            -234.0
# Df Residuals:                      53   BIC:                            -230.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.api as sm

X = l_context_df['BarCap High Yield_diff']

#for col in X.columns[X.isnull().any(axis=0)]:
#    X[col] = X[col].fillna(X[col].mean())
    
X = sm.add_constant(X)

Y = l_context_df['L_diff']

model_tca = sm.OLS(Y, X).fit()
model_tca.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 L_diff   R-squared:                       0.299
# Model:                            OLS   Adj. R-squared:                  0.286
# Method:                 Least Squares   F-statistic:                     22.66
# Date:                Sun, 16 Apr 2023   Prob (F-statistic):           1.54e-05
# Time:                        23:09:17   Log-Likelihood:                 117.21
# No. Observations:                  55   AIC:                            -230.4
# Df Residuals:                      53   BIC:                            -226.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Stepwise regression to find the three benchmarks which capture the highest R-squared

# %%
from mlxtend.feature_selection import SequentialFeatureSelector

# %%
X = l_new_df[l_reg_cols]
X = sm.add_constant(X)

Y = l_new_df['L_diff']

sfs = SequentialFeatureSelector(LinearRegression(),
                                k_features=3,
                                forward=True)
selected_features = sfs.fit(X, Y)

# %%
selected_features.k_feature_names_
# Out:
# ('CSI 300 TR USD_diff', 'DJ MN Momentum_diff', 'DJ MN Quality_diff')

# %%
selected_features.get_params()
# Out:
# {'clone_estimator': True,
#  'cv': 5,
#  'estimator__copy_X': True,
#  'estimator__fit_intercept': True,
#  'estimator__n_jobs': None,
#  'estimator__normalize': 'deprecated',
#  'estimator__positive': False,
#  'estimator': LinearRegression(),
#  'feature_groups': None,
#  'fixed_features': None,
#  'floating': False,
#  'forward': True,
#  'k_features': (3, 3),
#  'n_jobs': 1,
#  'pre_dispatch': '2*n_jobs',
#  'scoring': 'r2',
#  'verbose': 0,
#  'linearregression': LinearRegression(),
#  'linearregression__copy_X': True,
#  'linearregression__fit_intercept': True,
#  'linearregression__n_jobs': None,
#  'linearregression__normalize': 'deprecated',
#  'linearregression__positive': False}

# %%
selected_features.get_metric_dict()
# Out:
# {1: {'feature_idx': (11,),
#   'cv_scores': array([-0.11317024,  0.55538831, -0.39476939, -0.12417314,  0.01453298]),
#   'avg_score': -0.01243829457757888,
#   'feature_names': ('DJ MN Quality_diff',),
#   'ci_bound': 0.40316491747152594,
#   'std_dev': 0.3136760026301777,
#   'std_err': 0.15683800131508882},
#  2: {'feature_idx': (7, 11),
#   'cv_scores': array([ 0.22058686,  0.58753103, -0.36383509, -0.00665145,  0.07586556]),
#   'avg_score': 0.10269938315685889,
#   'feature_names': ('CSI 300 TR USD_diff', 'DJ MN Quality_diff'),
#   'ci_bound': 0.39793871396922087,
#   'std_dev': 0.30960983875407433,
#   'std_err': 0.15480491937703716},
#  3: {'feature_idx': (7, 8, 11),
#   'cv_scores': array([ 0.15218807,  0.59590714, -0.32096446, -0.0447197 ,  0.14501888]),
#   'avg_score': 0.1054859862355445,
#   'feature_names': ('CSI 300 TR USD_diff',
#    'DJ MN Momentum_diff',
#    'DJ MN Quality_diff'),
#   'ci_bound': 0.38502071864095294,
#   'std_dev': 0.29955919952192295,
# ...

# %% [markdown]
# ### The identified three benchmarks are:

# %%
selected_cols = list(selected_features.get_metric_dict()[3]['feature_names'])

selected_cols
# Out:
# ['CSI 300 TR USD_diff', 'DJ MN Momentum_diff', 'DJ MN Quality_diff']

# %% [markdown]
# ### Regression on just these three benchmarks

# %%
import statsmodels.api as sm

X = l_new_df[selected_cols]

for col in X.columns[X.isnull().any(axis=0)]:
    X[col] = X[col].fillna(X[col].mean())
    
X = sm.add_constant(X)

Y = l_new_df['L_diff']

model_tca = sm.OLS(Y, X).fit()
model_tca.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 L_diff   R-squared:                       0.400
# Model:                            OLS   Adj. R-squared:                  0.365
# Method:                 Least Squares   F-statistic:                     11.35
# Date:                Sun, 16 Apr 2023   Prob (F-statistic):           8.15e-06
# Time:                        23:09:18   Log-Likelihood:                 121.48
# No. Observations:                  55   AIC:                            -235.0
# Df Residuals:                      51   BIC:                            -226.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Observations:
#     High R-squared, but findings are not significant across the board

# %%
plot_l = pd.DataFrame()

# %%
#plot_d['Date'] = d_new_df['Date']

plot_l = l_new_df[selected_cols]

plot_l['Date'] = l_new_df['Date']

plot_l['L_diff'] = l_new_df['L_diff']

plot_l['Regression'] = model_tca.predict(X).values

# %%
plot_l
# Out:
# 0   CSI 300 TR USD_diff  DJ MN Momentum_diff  DJ MN Quality_diff       Date  \
# 0             -0.102477            -0.044635           -0.013575 2018-06-30
# 1             -0.022891            -0.003612            0.002371 2018-07-31
# 2             -0.052532             0.033171            0.009291 2018-08-31
# 3              0.022474            -0.007209           -0.012596 2018-09-30
# 4             -0.095399            -0.024482           -0.004514 2018-10-31
# ..                  ...                  ...                 ...        ...
# 51            -0.094676             0.046625            0.023152 2022-09-30
# 52            -0.103695             0.028171            0.006089 2022-10-31
# 53             0.115548            -0.028671            0.033639 2022-11-30
# 54             0.031598             0.025349            0.007579 2022-12-31
# 55             0.101648            -0.120666           -0.030167 2023-01-31
#
# 0     L_diff  Regression
# 0  -0.002513   -0.004434
# ...

# %%
#import matplotlib.pyplot as plt
#fig, ax = plt.subplots()
#plot_l.plot(x='Date', y=[col for col in plot_l.columns if col!='Date'], figsize=(20, 10), ax=ax, fontsize=16)
#for line in ax.get_lines():
#    if line.get_label() == 'L_diff' or line.get_label() == 'Regression':
#        line.set_linewidth(10)
#plt.show()



import matplotlib.pyplot as plt
fig, ax = plt.subplots()
plt.rcParams.update({'font.size': 15})
plot_l.plot(x='Date', y=[col for col in plot_l.columns if col!='Date'], figsize=(20, 10), ax=ax, fontsize=16, ylabel='Returns')
plt.legend(title='Legend')
plt.rcParams["legend.loc"] = 'upper left'
for line in ax.get_lines():
    if line.get_label() == 'L_diff' or line.get_label() == 'Regression':
        line.set_linewidth(10)
    else:
        line.set_dashes([5,2])
plt.show()

# %% [markdown]
# ### Recursive stepwise regression

# %%
selections = []

# %%
for n in range(2,10):
    
    X = l_new_df[l_reg_cols]
    X = sm.add_constant(X)
    
    Y = l_new_df['L_diff']
    
    sfs = SequentialFeatureSelector(LinearRegression(),
                                k_features=n,
                                forward=True)
    selected_features = sfs.fit(X, Y)
    print(list(selected_features.k_feature_names_))
    
    selections.append(list(selected_features.k_feature_names_))
    
    try:
        X = l_new_df[list(selected_features.k_feature_names_)]
        X = sm.add_constant(X)
    
        for col in X.columns[X.isnull().any(axis=0)]:
            X[col] = X[col].fillna(X[col].mean())

        model_tca = sm.OLS(Y, X).fit()
        print(model_tca.summary())
    except:
        continue
# Out:
# ['CSI 300 TR USD_diff', 'DJ MN Quality_diff']
#                             OLS Regression Results
# ...
# Dep. Variable:                 L_diff   R-squared:                       0.388
# Model:                            OLS   Adj. R-squared:                  0.364
# Method:                 Least Squares   F-statistic:                     16.47
# Date:                Sun, 16 Apr 2023   Prob (F-statistic):           2.89e-06
# Time:                        23:09:20   Log-Likelihood:                 120.91
# No. Observations:                  55   AIC:                            -235.8
# Df Residuals:                      52   BIC:                            -229.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Observations:
#     No meaningful inference is apparent from this stepwise regression above as it seems at odds with the contextual knowledge of the manager L

# %% [markdown]
# ## Selecting benchmarks based on given context of the constitution of portfolio manager L

# %%
for col in corr_cols:
    if col!='Cash':
        name=col+'_diff'
        l_context_df[name] = l_context_df[col] - l_context_df['Cash']
    else:
        continue

# %%
l_context_df['L_diff'] = l_context_df['L'] - l_context_df['Cash']

# %%
np.where(l_context_df['L_diff']<-0.7)
# Out:
# (array([], dtype=int64),)

# %%
l_context_df = l_context_df.drop(index=l_context_df.iloc[5].name)

# %%
selected_cols = ['Barclays US Covertible Bond Index', 'BarCap Global Agg', 'DJ MN Quality']
#['BarCap High Yield', 'BarCap Global Agg', 'DJ MN Quality']

selected_cols
# Out:
# ['Barclays US Covertible Bond Index', 'BarCap Global Agg', 'DJ MN Quality']

# %% [markdown]
# ### Regression on just these three benchmarks

# %%
import statsmodels.api as sm

X = l_context_df[selected_cols]

for col in X.columns[X.isnull().any(axis=0)]:
    X[col] = X[col].fillna(X[col].mean())
    
X = sm.add_constant(X)

Y = l_context_df['L_diff']

model_tca = sm.OLS(Y, X).fit()
model_tca.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 L_diff   R-squared:                       0.416
# Model:                            OLS   Adj. R-squared:                  0.381
# Method:                 Least Squares   F-statistic:                     11.90
# Date:                Sun, 16 Apr 2023   Prob (F-statistic):           5.37e-06
# Time:                        23:09:24   Log-Likelihood:                 120.20
# No. Observations:                  54   AIC:                            -232.4
# Df Residuals:                      50   BIC:                            -224.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %%
plot_l = pd.DataFrame()

# %%
#plot_d['Date'] = d_new_df['Date']

plot_l = l_context_df[selected_cols]

plot_l['Date'] = l_context_df['Date']

plot_l['L_diff'] = l_context_df['L_diff']

plot_l['Regression'] = model_tca.predict(X).values

# %%
plot_l
# Out:
# 0   Barclays US Covertible Bond Index  BarCap Global Agg  DJ MN Quality  \
# 0                           -0.001370          -0.004446      -0.012062
# 1                            0.004080          -0.001669       0.003994
# 2                            0.025390           0.001049       0.010977
# 3                           -0.006830          -0.008620      -0.010912
# 4                           -0.061310          -0.011171      -0.002694
# ..                                ...                ...            ...
# 51                          -0.058908          -0.051380       0.025111
# 52                           0.025937          -0.006877       0.008566
# 53                           0.019070           0.047061       0.036505
# 54                          -0.028017           0.005408       0.010953
# 55                           0.062162           0.032829      -0.026477
#
# 0        Date    L_diff  Regression
# 0  2018-06-30 -0.002513    0.009587
# ...

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
plot_l.plot(x='Date', y=[col for col in plot_l.columns if col!='Date'], figsize=(20, 10), ax=ax, fontsize=16)
for line in ax.get_lines():
    if line.get_label() == 'L_diff' or line.get_label() == 'Regression':
        line.set_linewidth(10)
plt.show()

# %% [markdown]
# ### Selecting 3 other indices based on context

# %%
selected_cols = ['BarCap High Yield', 'Barcap US MBS', 'DJ MN Quality']
#['BarCap High Yield', 'BarCap Global Agg', 'DJ MN Quality']

selected_cols
# Out:
# ['BarCap High Yield', 'Barcap US MBS', 'DJ MN Quality']

# %% [markdown]
# ### Regression on just these three benchmarks

# %%
import statsmodels.api as sm

X = l_context_df[selected_cols]

for col in X.columns[X.isnull().any(axis=0)]:
    X[col] = X[col].fillna(X[col].mean())
    
X = sm.add_constant(X)

Y = l_context_df['L_diff']

model_tca = sm.OLS(Y, X).fit()
model_tca.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 L_diff   R-squared:                       0.418
# Model:                            OLS   Adj. R-squared:                  0.383
# Method:                 Least Squares   F-statistic:                     11.96
# Date:                Sun, 16 Apr 2023   Prob (F-statistic):           5.09e-06
# Time:                        23:09:26   Log-Likelihood:                 120.26
# No. Observations:                  54   AIC:                            -232.5
# Df Residuals:                      50   BIC:                            -224.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
plot_l = pd.DataFrame()

# %%
#plot_d['Date'] = d_new_df['Date']

plot_l = l_context_df[selected_cols]

plot_l['Date'] = l_context_df['Date']

plot_l['L_diff'] = l_context_df['L_diff']

plot_l['Regression'] = model_tca.predict(X).values

# %%
plot_l
# Out:
# 0   BarCap High Yield  Barcap US MBS  DJ MN Quality       Date    L_diff  \
# 0            0.004015       0.000485      -0.012062 2018-06-30 -0.002513
# 1            0.010911      -0.001057       0.003994 2018-07-31 -0.002622
# 2            0.007374       0.006057       0.010977 2018-08-31  0.020314
# 3            0.005571      -0.006141      -0.010912 2018-09-30 -0.001684
# 4           -0.015985      -0.006305      -0.002694 2018-10-31 -0.001820
# ..                ...            ...            ...        ...       ...
# 51          -0.039716      -0.050513       0.025111 2022-09-30 -0.012660
# 52           0.025985      -0.014246       0.008566 2022-10-31 -0.039122
# 53           0.021704       0.040759       0.036505 2022-11-30 -0.003610
# 54          -0.006242      -0.004409       0.010953 2022-12-31  0.016042
# 55           0.038074       0.032945      -0.026477 2023-01-31  0.014390
#
# 0   Regression
# 0     0.012477
# 1     0.009452
# 2     0.002371
# 3     0.014785
# ...

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
plot_l.plot(x='Date', y=[col for col in plot_l.columns if col!='Date'], figsize=(20, 10), ax=ax, fontsize=16)
for line in ax.get_lines():
    if line.get_label() == 'L_diff' or line.get_label() == 'Regression':
        line.set_linewidth(10)
plt.show()

# %% [markdown]
# ### Another combo

# %%
selected_cols = ['BarCap High Yield', 'CSI 300 TR USD', 'DJ MN Quality']
#['BarCap High Yield', 'BarCap Global Agg', 'DJ MN Quality']

selected_cols
# Out:
# ['BarCap High Yield', 'CSI 300 TR USD', 'DJ MN Quality']

# %% [markdown]
# ### Regression on just these three benchmarks

# %%
import statsmodels.api as sm

X = l_context_df[selected_cols]

for col in X.columns[X.isnull().any(axis=0)]:
    X[col] = X[col].fillna(X[col].mean())
    
X = sm.add_constant(X)

Y = l_context_df['L_diff']

model_tca = sm.OLS(Y, X).fit()
model_tca.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 L_diff   R-squared:                       0.434
# Model:                            OLS   Adj. R-squared:                  0.400
# Method:                 Least Squares   F-statistic:                     12.76
# Date:                Sun, 16 Apr 2023   Prob (F-statistic):           2.59e-06
# Time:                        23:09:27   Log-Likelihood:                 121.01
# No. Observations:                  54   AIC:                            -234.0
# Df Residuals:                      50   BIC:                            -226.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
plot_l = pd.DataFrame()

# %%
#plot_d['Date'] = d_new_df['Date']

plot_l = l_context_df[selected_cols]

plot_l['Date'] = l_context_df['Date']

plot_l['L_diff'] = l_context_df['L_diff']

plot_l['Regression'] = model_tca.predict(X).values

# %%
plot_l
# Out:
# 0   BarCap High Yield  CSI 300 TR USD  DJ MN Quality       Date    L_diff  \
# 0            0.004015       -0.100964      -0.012062 2018-06-30 -0.002513
# 1            0.010911       -0.021269       0.003994 2018-07-31 -0.002622
# 2            0.007374       -0.050847       0.010977 2018-08-31  0.020314
# 3            0.005571        0.024158      -0.010912 2018-09-30 -0.001684
# 4           -0.015985       -0.093579      -0.002694 2018-10-31 -0.001820
# ..                ...             ...            ...        ...       ...
# 51          -0.039716       -0.092717       0.025111 2022-09-30 -0.012660
# 52           0.025985       -0.101218       0.008566 2022-10-31 -0.039122
# 53           0.021704        0.118414       0.036505 2022-11-30 -0.003610
# 54          -0.006242        0.034973       0.010953 2022-12-31  0.016042
# 55           0.038074        0.105339      -0.026477 2023-01-31  0.014390
#
# 0   Regression
# 0     0.003123
# 1     0.005270
# 2    -0.002118
# ...

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
plt.rcParams.update({'font.size': 15})
plot_l.plot(x='Date', y=[col for col in plot_l.columns if col!='Date'], figsize=(20, 10), ax=ax, fontsize=16, ylabel='Returns')
plt.legend(title='Legend')
plt.rcParams["legend.loc"] = 'upper left'
for line in ax.get_lines():
    if line.get_label() == 'L_diff' or line.get_label() == 'Regression':
        line.set_linewidth(10)
    else:
        line.set_dashes([5,2])
plt.show()

# %% [markdown]
# ## Outlier removed:
#
# ## Calculate return and risk measures:

# %%
ret_sel_cols = []

for col in selected_cols:
    ret_sel_cols.append(col.removesuffix('_diff'))

# %%
#ret_sel_cols.append('Cash')

ret_sel_cols
# Out:
# ['BarCap High Yield', 'CSI 300 TR USD', 'DJ MN Quality']

# %%
l_sel_df = l_new_df[ret_sel_cols]
l_sel_df['L'] = l_new_df['L']

#d_sel_df[selected_cols] = d_new_df[selected_cols]
#d_sel_df['D_diff'] = d_new_df['D_diff']

# %%
l_sel_df
# Out:
# 0   BarCap High Yield  CSI 300 TR USD  DJ MN Quality         L
# 0            0.004015       -0.100964      -0.012062 -0.001000
# 1            0.010911       -0.021269       0.003994 -0.001000
# 2            0.007374       -0.050847       0.010977  0.022000
# 3            0.005571        0.024158      -0.010912  0.000000
# 4           -0.015985       -0.093579      -0.002694  0.000000
# ..                ...             ...            ...       ...
# 51          -0.039716       -0.092717       0.025111 -0.010701
# 52           0.025985       -0.101218       0.008566 -0.036645
# 53           0.021704        0.118414       0.036505 -0.000744
# 54          -0.006242        0.034973       0.010953  0.019417
# 55           0.038074        0.105339      -0.026477  0.018081
#
# [56 rows x 4 columns]

# %%
am = l_sel_df.describe().iloc[1]

# %%
at = l_sel_df.sum()

# %%
from scipy import stats

# %%
gm = {}

# %%
for col in l_sel_df.columns:
    name = col+'_temp'
    l_sel_df[name] = l_sel_df[col]+1
    gm[col]=stats.gmean(l_sel_df.loc[:,name])-1

# %%
gm
# Out:
# {'BarCap High Yield': 0.0027546417435297954,
#  'CSI 300 TR USD': 0.0022943781800188745,
#  'DJ MN Quality': 0.0011408468178273345,
#  'L': -0.022185146345130802}

# %%
gm = pd.Series(gm)

gm
# Out:
# BarCap High Yield    0.002755
# CSI 300 TR USD       0.002294
# DJ MN Quality        0.001141
# L                   -0.022185
# dtype: float64

# %%
gt = np.exp(np.log(l_sel_df[[col for col in l_sel_df.columns if '_temp' in col]].prod(axis=0)))-1

# %%
gt.index = at.index

# %%
print(at)
print(am)
print(gt)
print(gm)
# Out:
# 0
# BarCap High Yield    0.175678
# CSI 300 TR USD       0.244785
# DJ MN Quality        0.083809
# L                   -0.413383
# dtype: float64
# 0
# BarCap High Yield    0.003137
# CSI 300 TR USD       0.004371
# DJ MN Quality        0.001497
# L                   -0.007382
# Name: mean, dtype: float64
# 0
# BarCap High Yield    0.166547
# CSI 300 TR USD       0.136937
# DJ MN Quality        0.065934
# L                   -0.715311
# dtype: float64
# BarCap High Yield    0.002755
# CSI 300 TR USD       0.002294
# DJ MN Quality        0.001141
# L                   -0.022185
# dtype: float64

# %%
return_measures = pd.DataFrame([at, am, gt, gm])

# %%
return_measures
# Out:
#            BarCap High Yield  CSI 300 TR USD  DJ MN Quality         L
# Unnamed 0           0.175678        0.244785       0.083809 -0.413383
# mean                0.003137        0.004371       0.001497 -0.007382
# Unnamed 1           0.166547        0.136937       0.065934 -0.715311
# Unnamed 2           0.002755        0.002294       0.001141 -0.022185

# %%
new_index = ['Arithmetic Total', 'Arithmetic Mean', 'Geometric Total', 'Geometric Mean']

return_measures = return_measures.set_index(pd.Index(new_index))

return_measures
# Out:
#                   BarCap High Yield  CSI 300 TR USD  DJ MN Quality         L
# Arithmetic Total           0.175678        0.244785       0.083809 -0.413383
# Arithmetic Mean            0.003137        0.004371       0.001497 -0.007382
# Geometric Total            0.166547        0.136937       0.065934 -0.715311
# Geometric Mean             0.002755        0.002294       0.001141 -0.022185

# %%
for col in return_measures.columns:
    if col!='L':
        name = 'L-'+col
        return_measures[name]= return_measures['L'] - return_measures[col]

# %%
return_measures
# Out:
#                   BarCap High Yield  CSI 300 TR USD  DJ MN Quality         L  \
# Arithmetic Total           0.175678        0.244785       0.083809 -0.413383
# Arithmetic Mean            0.003137        0.004371       0.001497 -0.007382
# Geometric Total            0.166547        0.136937       0.065934 -0.715311
# Geometric Mean             0.002755        0.002294       0.001141 -0.022185
#
#                   L-BarCap High Yield  L-CSI 300 TR USD  L-DJ MN Quality
# Arithmetic Total            -0.589061         -0.658167        -0.497191
# Arithmetic Mean             -0.010519         -0.011753        -0.008878
# Geometric Total             -0.881857         -0.852248        -0.781244
# Geometric Mean              -0.024940         -0.024480        -0.023326

# %%
for col in l_sel_df.columns:
    if '_temp' in col:
        l_sel_df.drop(columns = [col], inplace=True)

# %%
std_m = l_sel_df.describe().iloc[2]

# %%
std_a = std_m*np.sqrt(12)

# %%
std_a
# Out:
# 0
# BarCap High Yield    0.095480
# CSI 300 TR USD       0.226366
# DJ MN Quality        0.093878
# L                    0.391943
# Name: std, dtype: float64

# %%
risk_measures = pd.DataFrame([std_m, std_a])

# %%
risk_measures
# Out:
# 0    BarCap High Yield  CSI 300 TR USD  DJ MN Quality         L
# std           0.027563        0.065346       0.027100  0.113144
# std           0.095480        0.226366       0.093878  0.391943

# %%
new_index = ['Std Dev (Monthly)', 'Std Dev (Annually)']

risk_measures = risk_measures.set_index(pd.Index(new_index))

risk_measures
# Out:
# 0                   BarCap High Yield  CSI 300 TR USD  DJ MN Quality         L
# Std Dev (Monthly)            0.027563        0.065346       0.027100  0.113144
# Std Dev (Annually)           0.095480        0.226366       0.093878  0.391943

# %%
for col in risk_measures.columns:
    if col!='L':
        name = 'L-'+col
        risk_measures[name]= risk_measures['L'] - risk_measures[col]

# %%
risk_measures
# Out:
# 0                   BarCap High Yield  CSI 300 TR USD  DJ MN Quality  \
# Std Dev (Monthly)            0.027563        0.065346       0.027100
# Std Dev (Annually)           0.095480        0.226366       0.093878
#
# 0                          L  L-BarCap High Yield  L-CSI 300 TR USD  \
# Std Dev (Monthly)   0.113144             0.085582          0.047798
# Std Dev (Annually)  0.391943             0.296464          0.165578
#
# 0                   L-DJ MN Quality
# Std Dev (Monthly)          0.086044
# Std Dev (Annually)         0.298065

# %%
mean_cash = l_new_df['Cash'].mean()

# %%
l_sharpe_df = pd.DataFrame([{'Row':1}])

# %%
l_sharpe_df
# Out:
#    Row
# 0    1

# %%
for col in return_measures.columns:
    if '-' not in col:
        #print(return_measures.loc['Arithmetic Mean', col])
        #print(risk_measures.loc['Std Dev (Monthly)',col])
        
        #print((return_measures.loc['Arithmetic Mean', col]-mean_cash)/risk_measures.loc['Std Dev (Monthly)',col])
        #print()
        l_sharpe_df[col] = ((return_measures.loc['Arithmetic Mean', col]-mean_cash)/risk_measures.loc['Std Dev (Monthly)',col])

# %%
l_sharpe_df = l_sharpe_df.drop(columns = ['Row'])

l_sharpe_df
# Out:
#    BarCap High Yield  CSI 300 TR USD  DJ MN Quality         L
# 0           0.075393        0.050685       0.016143 -0.074603

# %%
for col in l_sharpe_df.columns:
    if '-' not in col and 'L'!=col:
        name = 'L-'+col
        l_sharpe_df[name]= l_sharpe_df['L'] - l_sharpe_df[col]

# %%
l_sharpe_df
# Out:
#    BarCap High Yield  CSI 300 TR USD  DJ MN Quality         L  \
# 0           0.075393        0.050685       0.016143 -0.074603
#
#    L-BarCap High Yield  L-CSI 300 TR USD  L-DJ MN Quality
# 0            -0.149996         -0.125288        -0.090746

# %% [markdown]
# ## Outlier retained:
#
# ## Calculate return and risk measures:

# %%
l_new_df = l_temp.copy()

# %%
ret_sel_cols = []

for col in selected_cols:
    ret_sel_cols.append(col.removesuffix('_diff'))

# %%
#ret_sel_cols.append('Cash')

ret_sel_cols
# Out:
# ['BarCap High Yield', 'CSI 300 TR USD', 'DJ MN Quality']

# %%
l_sel_df = l_new_df[ret_sel_cols]
l_sel_df['L'] = l_new_df['L']

#d_sel_df[selected_cols] = d_new_df[selected_cols]
#d_sel_df['D_diff'] = d_new_df['D_diff']

# %%
l_sel_df
# Out:
# 0   BarCap High Yield  CSI 300 TR USD  DJ MN Quality         L
# 0            0.004015       -0.100964      -0.012062 -0.001000
# 1            0.010911       -0.021269       0.003994 -0.001000
# 2            0.007374       -0.050847       0.010977  0.022000
# 3            0.005571        0.024158      -0.010912  0.000000
# 4           -0.015985       -0.093579      -0.002694  0.000000
# ..                ...             ...            ...       ...
# 51          -0.039716       -0.092717       0.025111 -0.010701
# 52           0.025985       -0.101218       0.008566 -0.036645
# 53           0.021704        0.118414       0.036505 -0.000744
# 54          -0.006242        0.034973       0.010953  0.019417
# 55           0.038074        0.105339      -0.026477  0.018081
#
# [56 rows x 4 columns]

# %%
am = l_sel_df.describe().iloc[1]

# %%
at = l_sel_df.sum()

# %%
from scipy import stats

# %%
gm = {}

# %%
for col in l_sel_df.columns:
    name = col+'_temp'
    l_sel_df[name] = l_sel_df[col]+1
    gm[col]=stats.gmean(l_sel_df.loc[:,name])-1

# %%
gm
# Out:
# {'BarCap High Yield': 0.0027546417435297954,
#  'CSI 300 TR USD': 0.0022943781800188745,
#  'DJ MN Quality': 0.0011408468178273345,
#  'L': -0.022185146345130802}

# %%
gm = pd.Series(gm)

gm
# Out:
# BarCap High Yield    0.002755
# CSI 300 TR USD       0.002294
# DJ MN Quality        0.001141
# L                   -0.022185
# dtype: float64

# %%
gt = np.exp(np.log(l_sel_df[[col for col in l_sel_df.columns if '_temp' in col]].prod(axis=0)))-1

# %%
gt.index = at.index

# %%
print(at)
print(am)
print(gt)
print(gm)
# Out:
# 0
# BarCap High Yield    0.175678
# CSI 300 TR USD       0.244785
# DJ MN Quality        0.083809
# L                   -0.413383
# dtype: float64
# 0
# BarCap High Yield    0.003137
# CSI 300 TR USD       0.004371
# DJ MN Quality        0.001497
# L                   -0.007382
# Name: mean, dtype: float64
# 0
# BarCap High Yield    0.166547
# CSI 300 TR USD       0.136937
# DJ MN Quality        0.065934
# L                   -0.715311
# dtype: float64
# BarCap High Yield    0.002755
# CSI 300 TR USD       0.002294
# DJ MN Quality        0.001141
# L                   -0.022185
# dtype: float64

# %%
return_measures = pd.DataFrame([at, am, gt, gm])

# %%
return_measures
# Out:
#            BarCap High Yield  CSI 300 TR USD  DJ MN Quality         L
# Unnamed 0           0.175678        0.244785       0.083809 -0.413383
# mean                0.003137        0.004371       0.001497 -0.007382
# Unnamed 1           0.166547        0.136937       0.065934 -0.715311
# Unnamed 2           0.002755        0.002294       0.001141 -0.022185

# %%
new_index = ['Arithmetic Total', 'Arithmetic Mean', 'Geometric Total', 'Geometric Mean']

return_measures = return_measures.set_index(pd.Index(new_index))

return_measures
# Out:
#                   BarCap High Yield  CSI 300 TR USD  DJ MN Quality         L
# Arithmetic Total           0.175678        0.244785       0.083809 -0.413383
# Arithmetic Mean            0.003137        0.004371       0.001497 -0.007382
# Geometric Total            0.166547        0.136937       0.065934 -0.715311
# Geometric Mean             0.002755        0.002294       0.001141 -0.022185

# %%
for col in return_measures.columns:
    if col!='L':
        name = 'L-'+col
        return_measures[name]= return_measures['L'] - return_measures[col]

# %%
return_measures
# Out:
#                   BarCap High Yield  CSI 300 TR USD  DJ MN Quality         L  \
# Arithmetic Total           0.175678        0.244785       0.083809 -0.413383
# Arithmetic Mean            0.003137        0.004371       0.001497 -0.007382
# Geometric Total            0.166547        0.136937       0.065934 -0.715311
# Geometric Mean             0.002755        0.002294       0.001141 -0.022185
#
#                   L-BarCap High Yield  L-CSI 300 TR USD  L-DJ MN Quality
# Arithmetic Total            -0.589061         -0.658167        -0.497191
# Arithmetic Mean             -0.010519         -0.011753        -0.008878
# Geometric Total             -0.881857         -0.852248        -0.781244
# Geometric Mean              -0.024940         -0.024480        -0.023326

# %%
for col in l_sel_df.columns:
    if '_temp' in col:
        l_sel_df.drop(columns = [col], inplace=True)

# %%
std_m = l_sel_df.describe().iloc[2]

# %%
std_a = std_m*np.sqrt(12)

# %%
std_a
# Out:
# 0
# BarCap High Yield    0.095480
# CSI 300 TR USD       0.226366
# DJ MN Quality        0.093878
# L                    0.391943
# Name: std, dtype: float64

# %%
risk_measures = pd.DataFrame([std_m, std_a])

# %%
risk_measures
# Out:
# 0    BarCap High Yield  CSI 300 TR USD  DJ MN Quality         L
# std           0.027563        0.065346       0.027100  0.113144
# std           0.095480        0.226366       0.093878  0.391943

# %%
new_index = ['Std Dev (Monthly)', 'Std Dev (Annually)']

risk_measures = risk_measures.set_index(pd.Index(new_index))

risk_measures
# Out:
# 0                   BarCap High Yield  CSI 300 TR USD  DJ MN Quality         L
# Std Dev (Monthly)            0.027563        0.065346       0.027100  0.113144
# Std Dev (Annually)           0.095480        0.226366       0.093878  0.391943

# %%
for col in risk_measures.columns:
    if col!='L':
        name = 'L-'+col
        risk_measures[name]= risk_measures['L'] - risk_measures[col]

# %%
risk_measures
# Out:
# 0                   BarCap High Yield  CSI 300 TR USD  DJ MN Quality  \
# Std Dev (Monthly)            0.027563        0.065346       0.027100
# Std Dev (Annually)           0.095480        0.226366       0.093878
#
# 0                          L  L-BarCap High Yield  L-CSI 300 TR USD  \
# Std Dev (Monthly)   0.113144             0.085582          0.047798
# Std Dev (Annually)  0.391943             0.296464          0.165578
#
# 0                   L-DJ MN Quality
# Std Dev (Monthly)          0.086044
# Std Dev (Annually)         0.298065

# %%
mean_cash = l_new_df['Cash'].mean()

# %%
l_sharpe_df = pd.DataFrame([{'Row':1}])

# %%
l_sharpe_df
# Out:
#    Row
# 0    1

# %%
for col in return_measures.columns:
    if '-' not in col:
        #print(return_measures.loc['Arithmetic Mean', col])
        #print(risk_measures.loc['Std Dev (Monthly)',col])
        
        #print((return_measures.loc['Arithmetic Mean', col]-mean_cash)/risk_measures.loc['Std Dev (Monthly)',col])
        #print()
        l_sharpe_df[col] = ((return_measures.loc['Arithmetic Mean', col]-mean_cash)/risk_measures.loc['Std Dev (Monthly)',col])

# %%
l_sharpe_df = l_sharpe_df.drop(columns = ['Row'])

l_sharpe_df
# Out:
#    BarCap High Yield  CSI 300 TR USD  DJ MN Quality         L
# 0           0.075393        0.050685       0.016143 -0.074603

# %%
for col in l_sharpe_df.columns:
    if '-' not in col and 'L'!=col:
        name = 'L-'+col
        l_sharpe_df[name]= l_sharpe_df['L'] - l_sharpe_df[col]

# %%
l_sharpe_df
# Out:
#    BarCap High Yield  CSI 300 TR USD  DJ MN Quality         L  \
# 0           0.075393        0.050685       0.016143 -0.074603
#
#    L-BarCap High Yield  L-CSI 300 TR USD  L-DJ MN Quality
# 0            -0.149996         -0.125288        -0.090746

# %% [markdown]
# ## Checking assumptions for applicability of Regression use case for Manager D

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %%
X = d_new_df[d_reg_cols]
X = sm.add_constant(X)
    
Y = d_new_df['D_diff']

# %%
lin_reg = LinearRegression()

lin_reg.fit(X, Y)
# Out:
# LinearRegression()

# %%
def calc_residuals(model, features, label):
    predictions = model.predict(features)
    df_results = pd.DataFrame({'Actual':label, 'Predicted':predictions})
    df_results['Residuals'] = abs(df_results['Actual']) - abs(df_results['Predicted'])
    
    return df_results

# %%
def linear_assumption(model, features, label):
    df_results = calc_residuals(model, features, label)
    
    sns.lmplot(x='Actual', y='Predicted', data=df_results, fit_reg=False, height=7)
    
    line_coords = np.arange(df_results.min().min(), df_results.max().max())
    plt.plot(line_coords, line_coords, color='darkorange', linestyle='--')
    plt.title('Actual v Predicted')
    plt.show()

# %%
linear_assumption(lin_reg, X, Y)

# %%
def normality_assumption(model, features, label, p_value_thresh=0.05):
    from statsmodels.stats.diagnostic import normal_ad
    
    df_results = calc_residuals(model, features, label)
    
    p_value = normal_ad(df_results['Residuals'])[1]
    
    if p_value <p_value_thresh:
        print('Residuals are not normally distributed')
    else:
        print('Residuals are normally distributed')
        
    plt.subplots(figsize=(12,6))
    plt.title('Distribution of Residuals')
    sns.histplot(df_results['Residuals'])
    plt.show()
    
    print()
    if p_value > p_value_thresh:
        print('Assumption satisified')
    else:
        print('Assumption not satsified, Confidence intervals will likely be affected')

# %%
normality_assumption(lin_reg, X, Y)
# Out:
# Residuals are normally distributed
# Assumption satisified

# %%
def multicollinearity_assumption(model, features, label, feature_names=None):
    """
    Multicollinearity: Assumes that predictors are not correlated with each other. If there is
                       correlation among the predictors, then either remove prepdictors with high
                       Variance Inflation Factor (VIF) values or perform dimensionality reduction
                           
                       This assumption being violated causes issues with interpretability of the 
                       coefficients and the standard errors of the coefficients.
    """
    from statsmodels.stats.outliers_influence import variance_inflation_factor
    print('Assumption 3: Little to no multicollinearity among predictors')
        
    # Plotting the heatmap
    plt.figure(figsize = (10,8))
    sns.heatmap(pd.DataFrame(features, columns=feature_names).corr(), annot=True)
    plt.title('Correlation of Variables')
    plt.show()
        
    print('Variance Inflation Factors (VIF)')
    print('> 10: An indication that multicollinearity may be present')
    print('> 100: Certain multicollinearity among the variables')
    print('-------------------------------------')
       
    # Gathering the VIF for each variable
    VIF = [variance_inflation_factor(features, i) for i in range(features.shape[1])]
    for idx, vif in enumerate(VIF):
        print('{0}: {1}'.format(feature_names[idx], vif))
        
    # Gathering and printing total cases of possible or definite multicollinearity
    possible_multicollinearity = sum([1 for vif in VIF if vif > 10])
    definite_multicollinearity = sum([1 for vif in VIF if vif > 100])
    print()
    print('{0} cases of possible multicollinearity'.format(possible_multicollinearity))
    print('{0} cases of definite multicollinearity'.format(definite_multicollinearity))
    print()

    if definite_multicollinearity == 0:
        if possible_multicollinearity == 0:
            print('Assumption satisfied')
        else:
            print('Assumption possibly satisfied')
            print()
            print('Coefficient interpretability may be problematic')
            print('Consider removing variables with a high Variance Inflation Factor (VIF)')

    else:
        print('Assumption not satisfied')
        print()
        print('Coefficient interpretability will be problematic')
        print('Consider removing variables with a high Variance Inflation Factor (VIF)')

# %%
multicollinearity_assumption(lin_reg, X, Y, feature_names=X.columns)
# Out:
# Assumption 3: Little to no multicollinearity among predictors
# Variance Inflation Factors (VIF)
# > 10: An indication that multicollinearity may be present
# > 100: Certain multicollinearity among the variables
# -------------------------------------
# const: 1.176198445529967
# MSCI ACWI_diff: 9.184825885802997
# BarCap US Agg_diff: 2.3873686572681354
# BarCap High Yield_diff: 8.168272295086995
# MSCI Emerging Markets_diff: 13.93644476024261
# MSCI China_diff: 8.027297295026687
# Newedge Trend Index_diff: 1.4613028558100858
# CSI 300 TR USD_diff: 3.8884613913799813
# DJ MN Momentum_diff: 4.142428359179275
# DJ MN Value_diff: 2.5395485021518156
# DJ MN Anti-Beta_diff: 3.4650908748518257
# DJ MN Quality_diff: 2.618965479488422
# DJ MN Size_diff: 2.7965081033281667
#
# 1 cases of possible multicollinearity
# 0 cases of definite multicollinearity
#
# Assumption possibly satisfied
#
# Coefficient interpretability may be problematic
# ...

# %%
def homoscedasticity_assumption(model, features, label):
    """
    Homoscedasticity: Assumes that the errors exhibit constant variance
    """
    print('Assumption 5: Homoscedasticity of Error Terms', '\n')
    
    print('Residuals should have relative constant variance')
        
    # Calculating residuals for the plot
    df_results = calc_residuals(model, features, label)

    # Plotting the residuals
    plt.subplots(figsize=(12, 6))
    ax = plt.subplot(111)  # To remove spines
    plt.scatter(x=df_results.index, y=df_results.Residuals, alpha=0.5)
    plt.plot(np.repeat(0, df_results.index.max()), color='darkorange', linestyle='--')
    ax.spines['right'].set_visible(False)  # Removing the right spine
    ax.spines['top'].set_visible(False)  # Removing the top spine
    plt.title('Residuals')
    plt.show()

# %%
homoscedasticity_assumption(lin_reg, X, Y)
# Out:
# Assumption 5: Homoscedasticity of Error Terms
#
# Residuals should have relative constant variance

# %% [markdown]
# ### Checking assumptions for applicability of regression use case for Manager L

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %%
X = l_new_df[l_reg_cols]
X = sm.add_constant(X)

Y = l_new_df['L_diff']

# %%
lin_reg = LinearRegression()

lin_reg.fit(X, Y)
# Out:
# LinearRegression()

# %%
linear_assumption(lin_reg, X, Y)

# %%
normality_assumption(lin_reg, X, Y)
# Out:
# Residuals are normally distributed
# Assumption satisified

# %%
multicollinearity_assumption(lin_reg, X, Y, feature_names=X.columns)
# Out:
# Assumption 3: Little to no multicollinearity among predictors
# Variance Inflation Factors (VIF)
# > 10: An indication that multicollinearity may be present
# > 100: Certain multicollinearity among the variables
# -------------------------------------
# const: 1.2688055553531803
# MSCI ACWI_diff: 9.643965432353326
# BarCap US Agg_diff: 2.703157695800554
# BarCap High Yield_diff: 8.836799119978789
# MSCI Emerging Markets_diff: 15.011242466501214
# MSCI China_diff: 8.305888891358983
# Newedge Trend Index_diff: 1.5237131854606987
# CSI 300 TR USD_diff: 3.8618528214728345
# DJ MN Momentum_diff: 4.376615550998247
# DJ MN Value_diff: 2.599289030043042
# DJ MN Anti-Beta_diff: 3.777350823149079
# DJ MN Quality_diff: 2.6555418692295767
# DJ MN Size_diff: 3.441765611043561
#
# 1 cases of possible multicollinearity
# 0 cases of definite multicollinearity
#
# Assumption possibly satisfied
#
# Coefficient interpretability may be problematic
# ...

# %%
homoscedasticity_assumption(lin_reg, X, Y)
# Out:
# Assumption 5: Homoscedasticity of Error Terms
#
# Residuals should have relative constant variance
